# %%
import puzzlerepresentation as P

# %%
import numpy as np

# %%
history = {}

# %%
def addChromosomeToHistory(C):
    history[C.tostring()] = 5000

# %%
h = (6,0)
null_C = np.zeros([10,3],dtype=np.int8)
if h:
    null_C[-1] = [h[0], h[1], 0]
addChromosomeToHistory(null_C)

# %%
def buildRandomChromosome(hole=None):
    C = np.random.randint(0, 7, size=(10,3), dtype=np.int8)
    C[:,-1] = np.random.randint(0,4, size=10, dtype=np.int8)
    if hole:
        C[-1] = [hole[0], hole[1], 0]
    if C.tostring() in history:
        return buildRandomChromosome(hole=hole)
    addChromosomeToHistory(C)
    return C

# %% [raw]
# def buildRandomChromosome(hole=None):
#     C = np.random.randint(0, 7, size=(10,3), dtype=np.int8)
#     C[:,-1] = np.random.randint(0,4, size=10, dtype=np.int8)
#     if hole:
#         C[-1] = [hole[0], hole[1], 0]
#     addChromosomeToHistory(C, history)
#     return C

# %%
h = (6,0)

# %%
pieces = P.pieces + [P.Piece('black',[[0,0]])]

# %%
def score(C):
    if history[C.tostring()] != 5000:
        return history[C.tostring()]
    A = np.zeros([7,7],dtype=np.int8)
    #pieces = P.pieces + [P.Piece('black',[[0,0]])]
    for i in range(10):
        for unit in pieces[i].rot_list(C[i,2]):
            x = C[i][0] + unit[0]
            y = C[i][1] + unit[1]
            if (min(x,y) < 0) or (max(x,y) > 6):
                return np.infty
            A[x][y] += 1
    #print(np.abs(A-1).sum())
    #print(A)
    s = np.abs(np.square(A-1)).sum()
    history[C.tostring()] = s
    return s

# %%
def rebuildChromosome(C, hole=None):
    C = C.reshape(10,3)
    
    C[:,:-1] = C[:,:-1] % 7
    C[:, -1] = C[:, -1] % 4
    
    return C

# %%
def stepChromosomes(C, hole=None):
    old_C = C.flatten()
    C_list = []
    iter_size = old_C.size
    if hole:
        iter_size -=3
    for x in range(iter_size):
        new_C_add = old_C.copy()
        new_C_sub = old_C.copy()
        
        new_C_add[x] += 1
        new_C_sub[x] -= 1
        
        new_C_add = rebuildChromosome(new_C_add).copy()
        new_C_sub = rebuildChromosome(new_C_sub).copy()
        
        if new_C_add.tostring() not in history:
            addChromosomeToHistory(new_C_add)
            C_list.append(new_C_add.copy())
        
        if new_C_sub.tostring() not in history:
            addChromosomeToHistory(new_C_sub)
            C_list.append(new_C_sub.copy())
        
    return C_list

# %%
C_list = [buildRandomChromosome(hole=h) for _ in range(10000)]

# %%
best_C = null_C.copy()
best_score = score(best_C)

# %%
for C in C_list:
    s = score(C)
    if s < best_score:
        best_C = C.copy()
        best_score = s
print(f'Search initialized with best score of: {best_score}.',end='')
# Out:
# Search initialized with best score of: 32.

# %%
def startSearch(hole=None):
    C_list = [buildRandomChromosome(hole=hole) for _ in range(10000)]
    best_C = null_C.copy()
    best_score = score(best_C)
    
    for C in C_list:
        s = score(C)
        if s < best_score:
            best_C = C.copy()
            best_score = s
    print(f'Search initialized with score of: {best_score}.')
    return [best_C]

# %%
best_C_list = [best_C]

# %%
i = 0

# %%
best_ever = best_score
best_chrom_ever = best_C.copy()
while(best_ever != 0):
    C_list = []
    for C in best_C_list:
        C_list = C_list + stepChromosomes(C, hole=h)
    two_steps = []
    for C in C_list:
        two_steps = two_steps + stepChromosomes(C, hole=h)
    C_list = C_list + two_steps
    best_C_list = []
    if len(C_list) == 0:
        print(f'Search ended with best score of {best_score}.')
        print(f'Restarting. {len(history):,} board positions searched, best score {best_ever}.  Loop: {i:,}.')
        best_C_list = startSearch(hole=h)
        best_score=np.infty
    for C in C_list:
        s = score(C)
        if s < best_score:
            best_C_list.append(C.copy())
            best_score = s
            if best_score < best_ever:
                best_ever = best_score
                best_chrom_ever = C.copy()
                print(f'New best score found with score = {best_ever}.')
    i += 1
# Out:
# New best score found with score = 26.
# New best score found with score = 24.
# New best score found with score = 22.
# New best score found with score = 20.
# New best score found with score = 18.
# New best score found with score = 16.
# New best score found with score = 14.
# New best score found with score = 12.
# New best score found with score = 10.
# New best score found with score = 8.
# Search ended with best score of 8.
# Restarting. 19,875 board positions searched, best score 8.  Loop: 5.
# Search initialized with score of: 26.
# Search ended with best score of 8.
# Restarting. 38,355 board positions searched, best score 8.  Loop: 12.
# Search initialized with score of: 34.
# Search ended with best score of 8.
# Restarting. 55,385 board positions searched, best score 8.  Loop: 17.
# Search initialized with score of: 32.
# Search ended with best score of 8.
# Restarting. 79,392 board positions searched, best score 8.  Loop: 26.
# Search initialized with score of: 30.
# Search ended with best score of 8.
# Restarting. 99,372 board positions searched, best score 8.  Loop: 33.
# Search initialized with score of: 26.
# New best score found with score = 6.
# Search ended with best score of 6.
# Restarting. 115,061 board positions searched, best score 6.  Loop: 38.
# Search initialized with score of: 28.
# Search ended with best score of 14.
# Restarting. 129,408 board positions searched, best score 6.  Loop: 41.
# Search initialized with score of: 32.
# Search ended with best score of 8.
# Restarting. 149,335 board positions searched, best score 6.  Loop: 49.
# Search initialized with score of: 28.
# Search ended with best score of 6.
# Restarting. 169,159 board positions searched, best score 6.  Loop: 55.
# Search initialized with score of: 28.
# Search ended with best score of 10.
# Restarting. 187,537 board positions searched, best score 6.  Loop: 61.
# Search initialized with score of: 34.
# Search ended with best score of 14.
# Restarting. 201,831 board positions searched, best score 6.  Loop: 65.
# Search initialized with score of: 36.
# Search ended with best score of 12.
# Restarting. 221,602 board positions searched, best score 6.  Loop: 71.
# Search initialized with score of: 20.
# Search ended with best score of 10.
# Restarting. 235,896 board positions searched, best score 6.  Loop: 75.
# Search initialized with score of: 36.
# Search ended with best score of 6.
# Restarting. 258,353 board positions searched, best score 6.  Loop: 82.
# Search initialized with score of: 32.
# Search ended with best score of 10.
# Restarting. 276,676 board positions searched, best score 6.  Loop: 87.
# Search initialized with score of: 34.
# Search ended with best score of 12.
# Restarting. 293,761 board positions searched, best score 6.  Loop: 91.
# Search initialized with score of: 26.
# Search ended with best score of 12.
# Restarting. 309,348 board positions searched, best score 6.  Loop: 95.
# Search initialized with score of: 30.
# Search ended with best score of 8.
# Restarting. 330,618 board positions searched, best score 6.  Loop: 102.
# Search initialized with score of: 30.
# Search ended with best score of 10.
# Restarting. 347,599 board positions searched, best score 6.  Loop: 107.
# Search initialized with score of: 26.
# Search ended with best score of 12.
# Restarting. 363,341 board positions searched, best score 6.  Loop: 112.
# Search initialized with score of: 32.
# Search ended with best score of 12.
# Restarting. 381,768 board positions searched, best score 6.  Loop: 118.
# Search initialized with score of: 26.
# Search ended with best score of 10.
# Restarting. 398,853 board positions searched, best score 6.  Loop: 123.
# Search initialized with score of: 26.
# Search ended with best score of 10.
# Restarting. 414,542 board positions searched, best score 6.  Loop: 128.
# Search initialized with score of: 26.
# Search ended with best score of 6.
# Restarting. 431,627 board positions searched, best score 6.  Loop: 133.
# Search initialized with score of: 28.
# Search ended with best score of 16.
# Restarting. 444,526 board positions searched, best score 6.  Loop: 136.
# Search initialized with score of: 28.
# Search ended with best score of 12.
# Restarting. 460,268 board positions searched, best score 6.  Loop: 141.
# Search initialized with score of: 24.
# Search ended with best score of 12.
# Restarting. 474,563 board positions searched, best score 6.  Loop: 145.
# Search initialized with score of: 30.
# Search ended with best score of 6.
# Restarting. 495,833 board positions searched, best score 6.  Loop: 154.
# Search initialized with score of: 22.
# Search ended with best score of 12.
# Restarting. 510,127 board positions searched, best score 6.  Loop: 158.
# Search initialized with score of: 34.
# Search ended with best score of 10.
# Restarting. 528,503 board positions searched, best score 6.  Loop: 164.
# Search initialized with score of: 28.
# Search ended with best score of 14.
# Restarting. 545,535 board positions searched, best score 6.  Loop: 169.
# Search initialized with score of: 34.
# Search ended with best score of 8.
# Restarting. 562,567 board positions searched, best score 6.  Loop: 174.
# Search initialized with score of: 22.
# Search ended with best score of 10.
# Restarting. 575,466 board positions searched, best score 6.  Loop: 177.
# Search initialized with score of: 32.
# Search ended with best score of 12.
# Restarting. 592,445 board positions searched, best score 6.  Loop: 181.
# Search initialized with score of: 26.
# Search ended with best score of 12.
# Restarting. 608,134 board positions searched, best score 6.  Loop: 186.
# Search initialized with score of: 30.
# Search ended with best score of 12.
# Restarting. 626,718 board positions searched, best score 6.  Loop: 192.
# Search initialized with score of: 34.
# Search ended with best score of 10.
# Restarting. 646,490 board positions searched, best score 6.  Loop: 198.
# Search initialized with score of: 34.
# Search ended with best score of 12.
# Restarting. 663,420 board positions searched, best score 6.  Loop: 202.
# Search initialized with score of: 28.
# Search ended with best score of 14.
# Restarting. 677,663 board positions searched, best score 6.  Loop: 205.
# Search initialized with score of: 20.
# Search ended with best score of 10.
# Restarting. 691,906 board positions searched, best score 6.  Loop: 208.
# Search initialized with score of: 34.
# Search ended with best score of 12.
# Restarting. 707,543 board positions searched, best score 6.  Loop: 212.
# Search initialized with score of: 32.
# Search ended with best score of 12.
# Restarting. 721,786 board positions searched, best score 6.  Loop: 215.
# Search initialized with score of: 22.
# Search ended with best score of 10.
# Restarting. 734,685 board positions searched, best score 6.  Loop: 218.
# Search initialized with score of: 28.
# Search ended with best score of 8.
# Restarting. 753,164 board positions searched, best score 6.  Loop: 225.
# Search initialized with score of: 28.
# Search ended with best score of 16.
# Restarting. 768,853 board positions searched, best score 6.  Loop: 229.
# Search initialized with score of: 24.
# Search ended with best score of 10.
# Restarting. 783,147 board positions searched, best score 6.  Loop: 233.
# Search initialized with score of: 36.
# Search ended with best score of 8.
# Restarting. 805,706 board positions searched, best score 6.  Loop: 241.
# Search initialized with score of: 26.
# Search ended with best score of 12.
# Restarting. 820,000 board positions searched, best score 6.  Loop: 245.
# Search initialized with score of: 28.
# Search ended with best score of 8.
# Restarting. 837,033 board positions searched, best score 6.  Loop: 250.
# Search initialized with score of: 32.
# Search ended with best score of 12.
# Restarting. 849,985 board positions searched, best score 6.  Loop: 253.
# Search initialized with score of: 32.
# Search ended with best score of 12.
# Restarting. 867,018 board positions searched, best score 6.  Loop: 258.
# Search initialized with score of: 36.
# Search ended with best score of 10.
# Restarting. 886,788 board positions searched, best score 6.  Loop: 264.
# Search initialized with score of: 32.
# Search ended with best score of 12.
# Restarting. 903,925 board positions searched, best score 6.  Loop: 270.
# Search initialized with score of: 26.
# Search ended with best score of 8.
# Restarting. 922,458 board positions searched, best score 6.  Loop: 277.
# Search initialized with score of: 32.
# Search ended with best score of 10.
# Restarting. 940,834 board positions searched, best score 6.  Loop: 283.
# Search initialized with score of: 34.
# Search ended with best score of 8.
# Restarting. 962,156 board positions searched, best score 6.  Loop: 290.
# Search initialized with score of: 28.
# Search ended with best score of 10.
# Restarting. 980,582 board positions searched, best score 6.  Loop: 296.
# Search initialized with score of: 32.
# Search ended with best score of 12.
# Restarting. 999,061 board positions searched, best score 6.  Loop: 301.
# Search initialized with score of: 28.
# Search ended with best score of 12.
# Restarting. 1,016,198 board positions searched, best score 6.  Loop: 307.
# Search initialized with score of: 36.
# Search ended with best score of 8.
# Restarting. 1,036,020 board positions searched, best score 6.  Loop: 313.
# Search initialized with score of: 30.
# Search ended with best score of 18.
# Restarting. 1,050,263 board positions searched, best score 6.  Loop: 316.
# Search initialized with score of: 28.
# Search ended with best score of 10.
# Restarting. 1,068,536 board positions searched, best score 6.  Loop: 321.
# Search initialized with score of: 24.
# Search ended with best score of 8.
# Restarting. 1,087,016 board positions searched, best score 6.  Loop: 328.
# Search initialized with score of: 26.
# Search ended with best score of 8.
# Restarting. 1,105,441 board positions searched, best score 6.  Loop: 334.
# Search initialized with score of: 30.
# Search ended with best score of 12.
# Restarting. 1,119,736 board positions searched, best score 6.  Loop: 338.
# Search initialized with score of: 30.
# Search ended with best score of 14.
# Restarting. 1,135,323 board positions searched, best score 6.  Loop: 341.
# Search initialized with score of: 24.
# Search ended with best score of 12.
# Restarting. 1,149,617 board positions searched, best score 6.  Loop: 345.
# Search initialized with score of: 26.
# Search ended with best score of 10.
# Restarting. 1,166,756 board positions searched, best score 6.  Loop: 351.
# Search initialized with score of: 36.
# Search ended with best score of 10.
# Restarting. 1,183,892 board positions searched, best score 6.  Loop: 356.
# Search initialized with score of: 20.
# Search ended with best score of 12.
# Restarting. 1,196,791 board positions searched, best score 6.  Loop: 359.
# Search initialized with score of: 34.
# Search ended with best score of 12.
# Restarting. 1,213,875 board positions searched, best score 6.  Loop: 364.
# Search initialized with score of: 32.
# Search ended with best score of 12.
# Restarting. 1,229,617 board positions searched, best score 6.  Loop: 368.
# Search initialized with score of: 30.
# Search ended with best score of 12.
# Restarting. 1,246,753 board positions searched, best score 6.  Loop: 373.
# Search initialized with score of: 32.
# Search ended with best score of 10.
# Restarting. 1,263,783 board positions searched, best score 6.  Loop: 378.
# Search initialized with score of: 32.
# Search ended with best score of 14.
# Restarting. 1,279,370 board positions searched, best score 6.  Loop: 382.
# Search initialized with score of: 26.
# Search ended with best score of 10.
# Restarting. 1,296,454 board positions searched, best score 6.  Loop: 388.
# Search initialized with score of: 32.
# Search ended with best score of 16.
# Restarting. 1,310,697 board positions searched, best score 6.  Loop: 391.
# Search initialized with score of: 30.
# Search ended with best score of 12.
# Restarting. 1,329,024 board positions searched, best score 6.  Loop: 395.
# Search initialized with score of: 22.
# Search ended with best score of 6.
# Restarting. 1,346,005 board positions searched, best score 6.  Loop: 400.
# Search initialized with score of: 38.
# Search ended with best score of 14.
# Restarting. 1,363,141 board positions searched, best score 6.  Loop: 405.
# Search initialized with score of: 28.
# Search ended with best score of 10.
# Restarting. 1,378,778 board positions searched, best score 6.  Loop: 409.
# Search initialized with score of: 30.
# Search ended with best score of 18.
# Restarting. 1,391,677 board positions searched, best score 6.  Loop: 412.
# Search initialized with score of: 30.
# Search ended with best score of 10.
# Restarting. 1,410,053 board positions searched, best score 6.  Loop: 418.
# Search initialized with score of: 30.
# Search ended with best score of 12.
# Restarting. 1,425,742 board positions searched, best score 6.  Loop: 423.
# Search initialized with score of: 28.
# Search ended with best score of 12.
# Restarting. 1,442,723 board positions searched, best score 6.  Loop: 428.
# Search initialized with score of: 32.
# Search ended with best score of 14.
# Restarting. 1,459,652 board positions searched, best score 6.  Loop: 432.
# Search initialized with score of: 24.
# Search ended with best score of 8.
# Restarting. 1,472,551 board positions searched, best score 6.  Loop: 435.
# Search initialized with score of: 30.
# Search ended with best score of 12.
# Restarting. 1,488,241 board positions searched, best score 6.  Loop: 439.
# Search initialized with score of: 26.
# Search ended with best score of 10.
# Restarting. 1,506,720 board positions searched, best score 6.  Loop: 446.
# Search initialized with score of: 34.
# Search ended with best score of 14.
# Restarting. 1,522,307 board positions searched, best score 6.  Loop: 450.
# Search initialized with score of: 32.
# Search ended with best score of 16.
# Restarting. 1,539,446 board positions searched, best score 6.  Loop: 455.
# Search initialized with score of: 22.
# Search ended with best score of 12.
# Restarting. 1,553,793 board positions searched, best score 6.  Loop: 459.
# Search initialized with score of: 24.
# Search ended with best score of 18.
# Restarting. 1,566,692 board positions searched, best score 6.  Loop: 462.
# Search initialized with score of: 34.
# Search ended with best score of 12.
# Restarting. 1,582,381 board positions searched, best score 6.  Loop: 467.
# Search initialized with score of: 30.
# Search ended with best score of 10.
# Restarting. 1,600,754 board positions searched, best score 6.  Loop: 472.
# Search initialized with score of: 28.
# Search ended with best score of 10.
# Restarting. 1,619,078 board positions searched, best score 6.  Loop: 477.
# Search initialized with score of: 28.
# Search ended with best score of 16.
# Restarting. 1,634,768 board positions searched, best score 6.  Loop: 481.
# Search initialized with score of: 22.
# Search ended with best score of 12.
# Restarting. 1,649,115 board positions searched, best score 6.  Loop: 484.
# Search initialized with score of: 34.
# Search ended with best score of 12.
# Restarting. 1,667,593 board positions searched, best score 6.  Loop: 490.
# Search initialized with score of: 28.
# Search ended with best score of 8.
# Restarting. 1,684,574 board positions searched, best score 6.  Loop: 495.
# Search initialized with score of: 28.
# Search ended with best score of 14.
# Restarting. 1,698,868 board positions searched, best score 6.  Loop: 499.
# Search initialized with score of: 30.
# Search ended with best score of 10.
# Restarting. 1,715,849 board positions searched, best score 6.  Loop: 504.
# Search initialized with score of: 28.
# Search ended with best score of 10.
# Restarting. 1,732,933 board positions searched, best score 6.  Loop: 509.
# Search initialized with score of: 32.
# Search ended with best score of 14.
# Restarting. 1,750,017 board positions searched, best score 6.  Loop: 515.
# Search initialized with score of: 34.
# Search ended with best score of 8.
# Restarting. 1,769,787 board positions searched, best score 6.  Loop: 521.
# Search initialized with score of: 28.
# Search ended with best score of 12.
# Restarting. 1,786,821 board positions searched, best score 6.  Loop: 526.
# Search initialized with score of: 30.
# Search ended with best score of 10.
# Restarting. 1,801,168 board positions searched, best score 6.  Loop: 530.
# Search initialized with score of: 28.
# Search ended with best score of 10.
# Restarting. 1,816,857 board positions searched, best score 6.  Loop: 534.
# Search initialized with score of: 32.
# Search ended with best score of 10.
# Restarting. 1,833,994 board positions searched, best score 6.  Loop: 540.
# Search initialized with score of: 26.
# Search ended with best score of 10.
# Restarting. 1,851,078 board positions searched, best score 6.  Loop: 545.
# Search initialized with score of: 26.
# Search ended with best score of 8.
# Restarting. 1,865,425 board positions searched, best score 6.  Loop: 549.
# Search initialized with score of: 28.
# Search ended with best score of 10.
# Restarting. 1,885,247 board positions searched, best score 6.  Loop: 556.
# Search initialized with score of: 28.
# Search ended with best score of 14.
# Restarting. 1,900,989 board positions searched, best score 6.  Loop: 560.
# Search initialized with score of: 24.
# Search ended with best score of 10.
# Restarting. 1,913,888 board positions searched, best score 6.  Loop: 563.
# Search initialized with score of: 28.
# Search ended with best score of 12.
# Restarting. 1,928,182 board positions searched, best score 6.  Loop: 567.
# Search initialized with score of: 26.
# Search ended with best score of 12.
# Restarting. 1,943,769 board positions searched, best score 6.  Loop: 571.
# Search initialized with score of: 24.
# Search ended with best score of 12.
# Restarting. 1,959,356 board positions searched, best score 6.  Loop: 575.
# Search initialized with score of: 22.
# Search ended with best score of 12.
# Restarting. 1,973,650 board positions searched, best score 6.  Loop: 579.
# Search initialized with score of: 22.
# Search ended with best score of 10.
# Restarting. 1,989,339 board positions searched, best score 6.  Loop: 584.
# Search initialized with score of: 24.
# Search ended with best score of 14.
# Restarting. 2,002,238 board positions searched, best score 6.  Loop: 587.
# Search initialized with score of: 24.
# Search ended with best score of 14.
# Restarting. 2,016,532 board positions searched, best score 6.  Loop: 591.
# Search initialized with score of: 32.
# Search ended with best score of 14.
# Restarting. 2,030,775 board positions searched, best score 6.  Loop: 594.
# Search initialized with score of: 30.
# Search ended with best score of 16.
# Restarting. 2,046,516 board positions searched, best score 6.  Loop: 598.
# Search initialized with score of: 40.
# Search ended with best score of 10.
# Restarting. 2,067,530 board positions searched, best score 6.  Loop: 604.
# Search initialized with score of: 24.
# Search ended with best score of 16.
# Restarting. 2,081,824 board positions searched, best score 6.  Loop: 607.
# Search initialized with score of: 28.
# Search ended with best score of 12.
# Restarting. 2,098,908 board positions searched, best score 6.  Loop: 612.
# Search initialized with score of: 36.
# Search ended with best score of 14.
# Restarting. 2,115,941 board positions searched, best score 6.  Loop: 617.
# Search initialized with score of: 30.
# Search ended with best score of 10.
# Restarting. 2,134,471 board positions searched, best score 6.  Loop: 622.
# Search initialized with score of: 24.
# Search ended with best score of 10.
# Restarting. 2,150,160 board positions searched, best score 6.  Loop: 627.
# Search initialized with score of: 34.
# Search ended with best score of 12.
# Restarting. 2,168,536 board positions searched, best score 6.  Loop: 633.
# Search initialized with score of: 30.
# Search ended with best score of 12.
# Restarting. 2,184,225 board positions searched, best score 6.  Loop: 637.
# Search initialized with score of: 36.
# Search ended with best score of 14.
# Restarting. 2,201,310 board positions searched, best score 6.  Loop: 643.
# Search initialized with score of: 28.
# Search ended with best score of 12.
# Restarting. 2,217,053 board positions searched, best score 6.  Loop: 648.
# Search initialized with score of: 34.
# Search ended with best score of 14.
# Restarting. 2,235,427 board positions searched, best score 6.  Loop: 653.
# Search initialized with score of: 30.
# Search ended with best score of 12.
# Restarting. 2,252,511 board positions searched, best score 6.  Loop: 658.
# Search initialized with score of: 26.
# Search ended with best score of 8.
# Restarting. 2,269,544 board positions searched, best score 6.  Loop: 663.
# Search initialized with score of: 24.
# Search ended with best score of 8.
# Restarting. 2,286,574 board positions searched, best score 6.  Loop: 668.
# Search initialized with score of: 30.
# Search ended with best score of 10.
# Restarting. 2,303,713 board positions searched, best score 6.  Loop: 674.
# Search initialized with score of: 34.
# Search ended with best score of 20.
# Restarting. 2,319,454 board positions searched, best score 6.  Loop: 678.
# Search initialized with score of: 28.
# Search ended with best score of 12.
# Restarting. 2,336,436 board positions searched, best score 6.  Loop: 683.
# Search initialized with score of: 32.
# Search ended with best score of 16.
# Restarting. 2,352,178 board positions searched, best score 6.  Loop: 688.
# Search initialized with score of: 16.
# Search ended with best score of 10.
# Restarting. 2,366,472 board positions searched, best score 6.  Loop: 692.
# Search initialized with score of: 28.
# Search ended with best score of 12.
# Restarting. 2,380,766 board positions searched, best score 6.  Loop: 696.
# Search initialized with score of: 22.
# Search ended with best score of 10.
# Restarting. 2,395,060 board positions searched, best score 6.  Loop: 700.
# Search initialized with score of: 34.
# Search ended with best score of 14.
# Restarting. 2,412,144 board positions searched, best score 6.  Loop: 706.
# Search initialized with score of: 28.
# Search ended with best score of 20.
# Restarting. 2,425,043 board positions searched, best score 6.  Loop: 709.
# Search initialized with score of: 34.
# Search ended with best score of 8.
# Restarting. 2,446,105 board positions searched, best score 6.  Loop: 715.
# Search initialized with score of: 32.
# Search ended with best score of 10.
# Restarting. 2,464,581 board positions searched, best score 6.  Loop: 719.
# Search initialized with score of: 30.
# Search ended with best score of 10.
# Restarting. 2,481,668 board positions searched, best score 6.  Loop: 724.
# Search initialized with score of: 30.
# Search ended with best score of 10.
# Restarting. 2,500,095 board positions searched, best score 6.  Loop: 729.
# Search initialized with score of: 30.
# Search ended with best score of 10.
# Restarting. 2,518,626 board positions searched, best score 6.  Loop: 735.
# Search initialized with score of: 40.
# Search ended with best score of 12.
# Restarting. 2,535,556 board positions searched, best score 6.  Loop: 739.
# Search initialized with score of: 26.
# Search ended with best score of 14.
# Restarting. 2,549,850 board positions searched, best score 6.  Loop: 743.
# Search initialized with score of: 32.
# Search ended with best score of 12.
# Restarting. 2,565,488 board positions searched, best score 6.  Loop: 747.
# Search initialized with score of: 38.
# Search ended with best score of 10.
# Restarting. 2,585,310 board positions searched, best score 6.  Loop: 754.
# Search initialized with score of: 20.
# Search ended with best score of 12.
# Restarting. 2,598,209 board positions searched, best score 6.  Loop: 757.
# Search initialized with score of: 28.
# Search ended with best score of 12.
# Restarting. 2,612,503 board positions searched, best score 6.  Loop: 761.
# Search initialized with score of: 30.
# Search ended with best score of 12.
# Restarting. 2,628,090 board positions searched, best score 6.  Loop: 765.
# Search initialized with score of: 30.
# Search ended with best score of 14.
# Restarting. 2,645,120 board positions searched, best score 6.  Loop: 769.
# Search initialized with score of: 28.
# Search ended with best score of 8.
# Restarting. 2,663,651 board positions searched, best score 6.  Loop: 775.
# Search initialized with score of: 30.
# Search ended with best score of 8.
# Restarting. 2,682,185 board positions searched, best score 6.  Loop: 782.
# Search initialized with score of: 22.
# Search ended with best score of 6.
# Restarting. 2,699,269 board positions searched, best score 6.  Loop: 788.
# Search initialized with score of: 22.
# Search ended with best score of 12.
# Restarting. 2,713,563 board positions searched, best score 6.  Loop: 791.
# Search initialized with score of: 20.
# Search ended with best score of 14.
# Restarting. 2,725,066 board positions searched, best score 6.  Loop: 793.
# Search initialized with score of: 32.
# Search ended with best score of 6.
# Restarting. 2,740,756 board positions searched, best score 6.  Loop: 797.
# Search initialized with score of: 20.
# Search ended with best score of 12.
# Restarting. 2,753,655 board positions searched, best score 6.  Loop: 800.
# Search initialized with score of: 32.
# Search ended with best score of 14.
# Restarting. 2,770,740 board positions searched, best score 6.  Loop: 805.
# Search initialized with score of: 20.
# Search ended with best score of 10.
# Restarting. 2,784,983 board positions searched, best score 6.  Loop: 808.
# Search initialized with score of: 26.
# Search ended with best score of 8.
# Restarting. 2,804,754 board positions searched, best score 6.  Loop: 815.
# Search initialized with score of: 32.
# Search ended with best score of 6.
# Restarting. 2,827,215 board positions searched, best score 6.  Loop: 822.
# Search initialized with score of: 24.
# Search ended with best score of 6.
# Restarting. 2,847,087 board positions searched, best score 6.  Loop: 829.
# Search initialized with score of: 24.
# Search ended with best score of 12.
# Restarting. 2,862,776 board positions searched, best score 6.  Loop: 834.
# Search initialized with score of: 28.
# Search ended with best score of 12.
# Restarting. 2,881,050 board positions searched, best score 6.  Loop: 839.
# Search initialized with score of: 22.
# Search ended with best score of 8.
# Restarting. 2,895,345 board positions searched, best score 6.  Loop: 843.
# Search initialized with score of: 26.
# Search ended with best score of 10.
# Restarting. 2,911,087 board positions searched, best score 6.  Loop: 848.
# Search initialized with score of: 32.
# Search ended with best score of 12.
# Restarting. 2,929,619 board positions searched, best score 6.  Loop: 853.
# Search initialized with score of: 30.
# Search ended with best score of 12.
# Restarting. 2,947,943 board positions searched, best score 6.  Loop: 858.
# Search initialized with score of: 32.
# Search ended with best score of 6.
# Restarting. 2,970,609 board positions searched, best score 6.  Loop: 866.
# Search initialized with score of: 32.
# Search ended with best score of 8.
# Restarting. 2,990,533 board positions searched, best score 6.  Loop: 872.
# Search initialized with score of: 26.
# Search ended with best score of 8.
# Restarting. 3,007,618 board positions searched, best score 6.  Loop: 878.
# Search initialized with score of: 30.
# Search ended with best score of 8.
# Restarting. 3,027,388 board positions searched, best score 6.  Loop: 883.
# Search initialized with score of: 32.
# Search ended with best score of 10.
# Restarting. 3,044,268 board positions searched, best score 6.  Loop: 887.
# Search initialized with score of: 28.
# Search ended with best score of 10.
# Restarting. 3,062,695 board positions searched, best score 6.  Loop: 893.
# Search initialized with score of: 36.
# Search ended with best score of 22.
# Restarting. 3,076,989 board positions searched, best score 6.  Loop: 897.
# Search initialized with score of: 26.
# Search ended with best score of 18.
# Restarting. 3,089,888 board positions searched, best score 6.  Loop: 900.
# Search initialized with score of: 28.
# Search ended with best score of 12.
# Restarting. 3,105,578 board positions searched, best score 6.  Loop: 904.
# Search initialized with score of: 34.
# Search ended with best score of 12.
# Restarting. 3,121,268 board positions searched, best score 6.  Loop: 908.
# Search initialized with score of: 26.
# Search ended with best score of 8.
# Restarting. 3,138,297 board positions searched, best score 6.  Loop: 912.
# Search initialized with score of: 28.
# Search ended with best score of 8.
# Restarting. 3,155,434 board positions searched, best score 6.  Loop: 918.
# Search initialized with score of: 30.
# Search ended with best score of 12.
# Restarting. 3,169,677 board positions searched, best score 6.  Loop: 921.
# Search initialized with score of: 24.
# Search ended with best score of 12.
# Restarting. 3,183,971 board positions searched, best score 6.  Loop: 925.
# Search initialized with score of: 28.
# Search ended with best score of 12.
# Restarting. 3,202,348 board positions searched, best score 6.  Loop: 930.
# Search initialized with score of: 26.
# Search ended with best score of 12.
# Restarting. 3,216,695 board positions searched, best score 6.  Loop: 934.
# Search initialized with score of: 32.
# Search ended with best score of 10.
# Restarting. 3,235,019 board positions searched, best score 6.  Loop: 939.
# Search initialized with score of: 30.
# Search ended with best score of 10.
# Restarting. 3,253,446 board positions searched, best score 6.  Loop: 945.
# Search initialized with score of: 30.
# Search ended with best score of 16.
# Restarting. 3,269,033 board positions searched, best score 6.  Loop: 949.
# Search initialized with score of: 32.
# Search ended with best score of 12.
# Restarting. 3,286,172 board positions searched, best score 6.  Loop: 954.
# Search initialized with score of: 34.
# Search ended with best score of 12.
# Restarting. 3,304,757 board positions searched, best score 6.  Loop: 961.
# Search initialized with score of: 30.
# Search ended with best score of 14.
# Restarting. 3,320,499 board positions searched, best score 6.  Loop: 966.
# Search initialized with score of: 28.
# Search ended with best score of 8.
# Restarting. 3,336,188 board positions searched, best score 6.  Loop: 971.
# Search initialized with score of: 32.
# Search ended with best score of 16.
# Restarting. 3,353,118 board positions searched, best score 6.  Loop: 975.
# Search initialized with score of: 34.
# Search ended with best score of 12.
# Restarting. 3,370,149 board positions searched, best score 6.  Loop: 979.
# Search initialized with score of: 30.
# Search ended with best score of 14.
# Restarting. 3,385,786 board positions searched, best score 6.  Loop: 983.
# Search initialized with score of: 36.
# Search ended with best score of 14.
# Restarting. 3,402,818 board positions searched, best score 6.  Loop: 988.
# Search initialized with score of: 26.
# Search ended with best score of 12.
# Restarting. 3,415,717 board positions searched, best score 6.  Loop: 991.
# Search initialized with score of: 34.
# Search ended with best score of 16.
# Restarting. 3,429,960 board positions searched, best score 6.  Loop: 994.
# Search initialized with score of: 32.
# Search ended with best score of 8.
# Restarting. 3,451,126 board positions searched, best score 6.  Loop: 1,001.
# Search initialized with score of: 26.
# Search ended with best score of 12.
# Restarting. 3,468,210 board positions searched, best score 6.  Loop: 1,007.
# Search initialized with score of: 28.
# Search ended with best score of 8.
# Restarting. 3,485,191 board positions searched, best score 6.  Loop: 1,012.
# Search initialized with score of: 32.
# Search ended with best score of 12.
# Restarting. 3,502,172 board positions searched, best score 6.  Loop: 1,017.
# Search initialized with score of: 28.
# Search ended with best score of 12.
# Restarting. 3,517,861 board positions searched, best score 6.  Loop: 1,021.
# Search initialized with score of: 30.
# Search ended with best score of 14.
# Restarting. 3,532,104 board positions searched, best score 6.  Loop: 1,024.
# Search initialized with score of: 24.
# Search ended with best score of 8.
# Restarting. 3,549,241 board positions searched, best score 6.  Loop: 1,029.
# Search initialized with score of: 34.
# Search ended with best score of 8.
# Restarting. 3,570,458 board positions searched, best score 6.  Loop: 1,035.
# Search initialized with score of: 34.
# Search ended with best score of 12.
# Restarting. 3,591,678 board positions searched, best score 6.  Loop: 1,042.
# Search initialized with score of: 22.
# Search ended with best score of 6.
# Restarting. 3,607,420 board positions searched, best score 6.  Loop: 1,047.
# Search initialized with score of: 30.
# Search ended with best score of 16.
# Restarting. 3,623,058 board positions searched, best score 6.  Loop: 1,050.
# Search initialized with score of: 26.
# Search ended with best score of 8.
# Restarting. 3,641,529 board positions searched, best score 6.  Loop: 1,055.
# Search initialized with score of: 24.
# Search ended with best score of 12.
# Restarting. 3,655,823 board positions searched, best score 6.  Loop: 1,059.
# Search initialized with score of: 26.
# Search ended with best score of 12.
# Restarting. 3,670,117 board positions searched, best score 6.  Loop: 1,063.
# Search initialized with score of: 20.
# Search ended with best score of 8.
# Restarting. 3,687,202 board positions searched, best score 6.  Loop: 1,068.
# Search initialized with score of: 34.
# Search ended with best score of 6.
# Restarting. 3,705,684 board positions searched, best score 6.  Loop: 1,073.
# Search initialized with score of: 30.
# Search ended with best score of 8.
# Restarting. 3,725,559 board positions searched, best score 6.  Loop: 1,080.
# Search initialized with score of: 32.
# Search ended with best score of 12.
# Restarting. 3,743,985 board positions searched, best score 6.  Loop: 1,085.
# Search initialized with score of: 24.
# Search ended with best score of 10.
# Restarting. 3,759,674 board positions searched, best score 6.  Loop: 1,090.
# Search initialized with score of: 32.
# Search ended with best score of 12.
# Restarting. 3,777,998 board positions searched, best score 6.  Loop: 1,095.
# Search initialized with score of: 30.
# Search ended with best score of 14.
# Restarting. 3,792,292 board positions searched, best score 6.  Loop: 1,099.
# Search initialized with score of: 26.
# Search ended with best score of 8.
# Restarting. 3,809,324 board positions searched, best score 6.  Loop: 1,104.
# Search initialized with score of: 30.
# Search ended with best score of 10.
# Restarting. 3,829,145 board positions searched, best score 6.  Loop: 1,110.
# Search initialized with score of: 30.
# Search ended with best score of 10.
# Restarting. 3,846,227 board positions searched, best score 6.  Loop: 1,115.
# Search initialized with score of: 32.
# Search ended with best score of 10.
# Restarting. 3,864,654 board positions searched, best score 6.  Loop: 1,120.
# Search initialized with score of: 32.
# Search ended with best score of 8.
# Restarting. 3,883,030 board positions searched, best score 6.  Loop: 1,126.
# Search initialized with score of: 30.
# Search ended with best score of 8.
# Restarting. 3,904,199 board positions searched, best score 6.  Loop: 1,133.
# Search initialized with score of: 22.
# Search ended with best score of 12.
# Restarting. 3,918,493 board positions searched, best score 6.  Loop: 1,137.
# Search initialized with score of: 30.
# Search ended with best score of 10.
# Restarting. 3,934,182 board positions searched, best score 6.  Loop: 1,141.
# Search initialized with score of: 32.
# Search ended with best score of 8.
# Restarting. 3,954,058 board positions searched, best score 6.  Loop: 1,148.
# Search initialized with score of: 28.
# Search ended with best score of 6.
# Restarting. 3,972,536 board positions searched, best score 6.  Loop: 1,154.
# Search initialized with score of: 20.
# Search ended with best score of 8.
# Restarting. 3,986,830 board positions searched, best score 6.  Loop: 1,158.
# Search initialized with score of: 26.
# Search ended with best score of 6.
# Restarting. 4,006,649 board positions searched, best score 6.  Loop: 1,164.
# Search initialized with score of: 32.
# Search ended with best score of 6.
# Restarting. 4,029,210 board positions searched, best score 6.  Loop: 1,173.
# Search initialized with score of: 30.
# Search ended with best score of 8.
# Restarting. 4,048,981 board positions searched, best score 6.  Loop: 1,180.
# Search initialized with score of: 24.
# Search ended with best score of 12.
# Restarting. 4,064,670 board positions searched, best score 6.  Loop: 1,185.
# Search initialized with score of: 24.
# Search ended with best score of 10.
# Restarting. 4,080,359 board positions searched, best score 6.  Loop: 1,190.
# Search initialized with score of: 34.
# Search ended with best score of 10.
# Restarting. 4,098,683 board positions searched, best score 6.  Loop: 1,195.
# Search initialized with score of: 28.
# Search ended with best score of 12.
# Restarting. 4,115,664 board positions searched, best score 6.  Loop: 1,200.
# Search initialized with score of: 22.
# Search ended with best score of 6.
# Restarting. 4,132,748 board positions searched, best score 6.  Loop: 1,206.
# Search initialized with score of: 28.
# Search ended with best score of 10.
# Restarting. 4,148,385 board positions searched, best score 6.  Loop: 1,210.
# Search initialized with score of: 30.
# Search ended with best score of 14.
# Restarting. 4,165,366 board positions searched, best score 6.  Loop: 1,215.
# Search initialized with score of: 30.
# Search ended with best score of 10.
# Restarting. 4,182,398 board positions searched, best score 6.  Loop: 1,220.
# Search initialized with score of: 32.
# Search ended with best score of 10.
# Restarting. 4,200,877 board positions searched, best score 6.  Loop: 1,225.
# Search initialized with score of: 24.
# Search ended with best score of 18.
# Restarting. 4,212,380 board positions searched, best score 6.  Loop: 1,227.
# Search initialized with score of: 28.
# Search ended with best score of 12.
# Restarting. 4,228,122 board positions searched, best score 6.  Loop: 1,232.
# Search initialized with score of: 30.
# Search ended with best score of 8.
# Restarting. 4,246,654 board positions searched, best score 6.  Loop: 1,238.
# Search initialized with score of: 20.
# Search ended with best score of 12.
# Restarting. 4,260,897 board positions searched, best score 6.  Loop: 1,241.
# Search initialized with score of: 24.
# Search ended with best score of 12.
# Restarting. 4,275,191 board positions searched, best score 6.  Loop: 1,245.
# Search initialized with score of: 26.
# Search ended with best score of 8.
# Restarting. 4,293,619 board positions searched, best score 6.  Loop: 1,251.
# Search initialized with score of: 24.
# Search ended with best score of 8.
# Restarting. 4,309,360 board positions searched, best score 6.  Loop: 1,255.
# Search initialized with score of: 24.
# Search ended with best score of 8.
# Restarting. 4,326,444 board positions searched, best score 6.  Loop: 1,260.
# Search initialized with score of: 26.
# Search ended with best score of 10.
# Restarting. 4,343,527 board positions searched, best score 6.  Loop: 1,265.
# Search initialized with score of: 28.
# Search ended with best score of 10.
# Restarting. 4,359,114 board positions searched, best score 6.  Loop: 1,269.
# Search initialized with score of: 30.
# Search ended with best score of 14.
# Restarting. 4,374,701 board positions searched, best score 6.  Loop: 1,273.
# Search initialized with score of: 32.
# Search ended with best score of 10.
# Restarting. 4,388,995 board positions searched, best score 6.  Loop: 1,277.
# Search initialized with score of: 32.
# Search ended with best score of 8.
# Restarting. 4,408,717 board positions searched, best score 6.  Loop: 1,283.
# Search initialized with score of: 30.
# Search ended with best score of 12.
# Restarting. 4,425,649 board positions searched, best score 6.  Loop: 1,287.
# Search initialized with score of: 24.
# Search ended with best score of 12.
# Restarting. 4,441,236 board positions searched, best score 6.  Loop: 1,291.
# Search initialized with score of: 26.
# Search ended with best score of 8.
# Restarting. 4,459,768 board positions searched, best score 6.  Loop: 1,298.
# Search initialized with score of: 30.
# Search ended with best score of 18.
# Restarting. 4,474,115 board positions searched, best score 6.  Loop: 1,301.
# Search initialized with score of: 32.
# Search ended with best score of 18.
# Restarting. 4,488,358 board positions searched, best score 6.  Loop: 1,304.
# Search initialized with score of: 26.
# Search ended with best score of 8.
# Restarting. 4,506,787 board positions searched, best score 6.  Loop: 1,310.
# Search initialized with score of: 38.
# Search ended with best score of 12.
# Restarting. 4,525,111 board positions searched, best score 6.  Loop: 1,315.
# Search initialized with score of: 30.
# Search ended with best score of 14.
# Restarting. 4,542,248 board positions searched, best score 6.  Loop: 1,320.
# Search initialized with score of: 28.
# Search ended with best score of 8.
# Restarting. 4,562,122 board positions searched, best score 6.  Loop: 1,328.
# Search initialized with score of: 24.
# Search ended with best score of 12.
# Restarting. 4,579,205 board positions searched, best score 6.  Loop: 1,333.
# Search initialized with score of: 24.
# Search ended with best score of 12.
# Restarting. 4,594,893 board positions searched, best score 6.  Loop: 1,337.
# Search initialized with score of: 28.
# Search ended with best score of 12.
# Restarting. 4,613,425 board positions searched, best score 6.  Loop: 1,342.
# Search initialized with score of: 30.
# Search ended with best score of 10.
# Restarting. 4,630,457 board positions searched, best score 6.  Loop: 1,347.
# Search initialized with score of: 28.
# Search ended with best score of 12.
# Restarting. 4,647,440 board positions searched, best score 6.  Loop: 1,351.
# Search initialized with score of: 26.
# Search ended with best score of 16.
# Restarting. 4,661,735 board positions searched, best score 6.  Loop: 1,355.
# Search initialized with score of: 30.
# Search ended with best score of 16.
# Restarting. 4,676,029 board positions searched, best score 6.  Loop: 1,359.
# Search initialized with score of: 26.
# Search ended with best score of 8.
# Restarting. 4,694,505 board positions searched, best score 6.  Loop: 1,365.
# Search initialized with score of: 32.
# Search ended with best score of 8.
# Restarting. 4,712,932 board positions searched, best score 6.  Loop: 1,371.
# Search initialized with score of: 24.
# Search ended with best score of 10.
# Restarting. 4,729,964 board positions searched, best score 6.  Loop: 1,376.
# Search initialized with score of: 24.
# Search ended with best score of 10.
# Restarting. 4,745,601 board positions searched, best score 6.  Loop: 1,380.
# Search initialized with score of: 26.
# Search ended with best score of 14.
# Restarting. 4,759,844 board positions searched, best score 6.  Loop: 1,383.
# Search initialized with score of: 28.
# Search ended with best score of 8.
# Restarting. 4,779,615 board positions searched, best score 6.  Loop: 1,389.
# Search initialized with score of: 26.
# Search ended with best score of 8.
# Restarting. 4,796,648 board positions searched, best score 6.  Loop: 1,394.
# Search initialized with score of: 32.
# Search ended with best score of 8.
# Restarting. 4,812,285 board positions searched, best score 6.  Loop: 1,398.
# Search initialized with score of: 26.
# Search ended with best score of 8.
# Restarting. 4,832,107 board positions searched, best score 6.  Loop: 1,405.
# Search initialized with score of: 36.
# Search ended with best score of 12.
# Restarting. 4,850,483 board positions searched, best score 6.  Loop: 1,411.
# Search initialized with score of: 26.
# Search ended with best score of 14.
# Restarting. 4,866,225 board positions searched, best score 6.  Loop: 1,416.
# Search initialized with score of: 28.
# Search ended with best score of 8.
# Restarting. 4,885,995 board positions searched, best score 6.  Loop: 1,422.
# Search initialized with score of: 34.
# Search ended with best score of 12.
# Restarting. 4,903,133 board positions searched, best score 6.  Loop: 1,428.
# Search initialized with score of: 28.
# Search ended with best score of 12.
# Restarting. 4,918,822 board positions searched, best score 6.  Loop: 1,433.
# Search initialized with score of: 30.
# Search ended with best score of 14.
# Restarting. 4,934,409 board positions searched, best score 6.  Loop: 1,437.
# Search initialized with score of: 28.
# Search ended with best score of 10.
# Restarting. 4,952,991 board positions searched, best score 6.  Loop: 1,443.
# Search initialized with score of: 26.
# Search ended with best score of 12.
# Restarting. 4,968,681 board positions searched, best score 6.  Loop: 1,448.
# Search initialized with score of: 26.
# Search ended with best score of 6.
# Restarting. 4,987,056 board positions searched, best score 6.  Loop: 1,454.
# Search initialized with score of: 30.
# Search ended with best score of 12.
# Restarting. 5,004,087 board positions searched, best score 6.  Loop: 1,459.
# Search initialized with score of: 30.
# Search ended with best score of 12.
# Restarting. 5,022,560 board positions searched, best score 6.  Loop: 1,465.
# Search initialized with score of: 28.
# Search ended with best score of 10.
# Restarting. 5,039,644 board positions searched, best score 6.  Loop: 1,470.
# Search initialized with score of: 32.
# Search ended with best score of 12.
# Restarting. 5,055,387 board positions searched, best score 6.  Loop: 1,474.
# Search initialized with score of: 38.
# Search ended with best score of 20.
# Restarting. 5,069,734 board positions searched, best score 6.  Loop: 1,478.
# Search initialized with score of: 32.
# Search ended with best score of 10.
# Restarting. 5,085,423 board positions searched, best score 6.  Loop: 1,483.
# Search initialized with score of: 32.
# Search ended with best score of 12.
# Restarting. 5,102,508 board positions searched, best score 6.  Loop: 1,488.
# Search initialized with score of: 32.
# Search ended with best score of 12.
# Restarting. 5,119,538 board positions searched, best score 6.  Loop: 1,492.
# Search initialized with score of: 30.
# Search ended with best score of 12.
# Restarting. 5,136,728 board positions searched, best score 6.  Loop: 1,497.
# Search initialized with score of: 38.
# Search ended with best score of 14.
# Restarting. 5,155,158 board positions searched, best score 6.  Loop: 1,502.
# Search initialized with score of: 34.
# Search ended with best score of 14.
# Restarting. 5,170,847 board positions searched, best score 6.  Loop: 1,506.
# Search initialized with score of: 32.
# Search ended with best score of 10.
# Restarting. 5,189,276 board positions searched, best score 6.  Loop: 1,512.
# Search initialized with score of: 28.
# Search ended with best score of 8.
# Restarting. 5,206,357 board positions searched, best score 6.  Loop: 1,517.
# Search initialized with score of: 20.
# Search ended with best score of 12.
# Restarting. 5,220,600 board positions searched, best score 6.  Loop: 1,520.
# Search initialized with score of: 28.
# Search ended with best score of 14.
# Restarting. 5,233,499 board positions searched, best score 6.  Loop: 1,523.
# Search initialized with score of: 24.
# Search ended with best score of 14.
# Restarting. 5,247,794 board positions searched, best score 6.  Loop: 1,526.
# Search initialized with score of: 26.
# Search ended with best score of 10.
# Restarting. 5,263,431 board positions searched, best score 6.  Loop: 1,530.
# Search initialized with score of: 30.
# Search ended with best score of 10.
# Restarting. 5,281,911 board positions searched, best score 6.  Loop: 1,536.
# Search initialized with score of: 28.
# Search ended with best score of 10.
# Restarting. 5,298,944 board positions searched, best score 6.  Loop: 1,541.
# Search initialized with score of: 28.
# Search ended with best score of 10.
# Restarting. 5,314,632 board positions searched, best score 6.  Loop: 1,545.
# Search initialized with score of: 24.
# Search ended with best score of 16.
# Restarting. 5,327,531 board positions searched, best score 6.  Loop: 1,548.
# Search initialized with score of: 38.
# Search ended with best score of 6.
# Restarting. 5,350,143 board positions searched, best score 6.  Loop: 1,557.
# Search initialized with score of: 36.
# Search ended with best score of 6.
# Restarting. 5,371,462 board positions searched, best score 6.  Loop: 1,565.
# Search initialized with score of: 30.
# Search ended with best score of 14.
# Restarting. 5,385,757 board positions searched, best score 6.  Loop: 1,569.
# Search initialized with score of: 30.
# Search ended with best score of 10.
# ...
# Restarting. 8,369,140 board positions searched, best score 4.  Loop: 2,456.
# Search initialized with score of: 30.
# Search ended with best score of 6.
# Restarting. 8,389,068 board positions searched, best score 4.  Loop: 2,462.
# Search initialized with score of: 22.
# Search ended with best score of 6.
# Restarting. 8,406,100 board positions searched, best score 4.  Loop: 2,467.
# Search initialized with score of: 20.
# Search ended with best score of 8.
# Restarting. 8,421,788 board positions searched, best score 4.  Loop: 2,471.
# Search initialized with score of: 32.
# Search ended with best score of 12.
# Restarting. 8,440,319 board positions searched, best score 4.  Loop: 2,477.
# Search initialized with score of: 34.
# Search ended with best score of 10.
# Restarting. 8,460,246 board positions searched, best score 4.  Loop: 2,483.
# Search initialized with score of: 26.
# Search ended with best score of 16.
# Restarting. 8,473,145 board positions searched, best score 4.  Loop: 2,486.
# Search initialized with score of: 28.
# Search ended with best score of 12.
# Restarting. 8,491,677 board positions searched, best score 4.  Loop: 2,493.
# Search initialized with score of: 24.
# Search ended with best score of 10.
# Restarting. 8,510,104 board positions searched, best score 4.  Loop: 2,498.
# Search initialized with score of: 26.
# Search ended with best score of 12.
# Restarting. 8,524,398 board positions searched, best score 4.  Loop: 2,502.
# Search initialized with score of: 30.
# Search ended with best score of 6.
# Restarting. 8,544,117 board positions searched, best score 4.  Loop: 2,508.
# Search initialized with score of: 32.
# Search ended with best score of 12.
# Restarting. 8,559,754 board positions searched, best score 4.  Loop: 2,512.
# Search initialized with score of: 32.
# Search ended with best score of 12.
# Restarting. 8,579,628 board positions searched, best score 4.  Loop: 2,518.
# Search initialized with score of: 34.
# Search ended with best score of 10.
# Restarting. 8,600,745 board positions searched, best score 4.  Loop: 2,525.
# Search initialized with score of: 42.
# Search ended with best score of 10.
# Restarting. 8,623,463 board positions searched, best score 4.  Loop: 2,534.
# Search initialized with score of: 32.
# Search ended with best score of 10.
# Restarting. 8,643,337 board positions searched, best score 4.  Loop: 2,540.
# Search initialized with score of: 28.
# Search ended with best score of 16.
# Restarting. 8,657,632 board positions searched, best score 4.  Loop: 2,543.
# Search initialized with score of: 34.
# Search ended with best score of 16.
# Restarting. 8,673,168 board positions searched, best score 4.  Loop: 2,546.
# Search initialized with score of: 32.
# Search ended with best score of 8.
# Restarting. 8,694,437 board positions searched, best score 4.  Loop: 2,554.
# Search initialized with score of: 34.
# Search ended with best score of 16.
# Restarting. 8,710,126 board positions searched, best score 4.  Loop: 2,559.
# Search initialized with score of: 38.
# Search ended with best score of 14.
# Restarting. 8,729,895 board positions searched, best score 4.  Loop: 2,564.
# Search initialized with score of: 30.
# Search ended with best score of 14.
# Restarting. 8,745,582 board positions searched, best score 4.  Loop: 2,568.
# Search initialized with score of: 34.
# Search ended with best score of 16.
# Restarting. 8,761,271 board positions searched, best score 4.  Loop: 2,572.
# Search initialized with score of: 28.
# Search ended with best score of 14.
# Restarting. 8,776,961 board positions searched, best score 4.  Loop: 2,576.
# Search initialized with score of: 24.
# Search ended with best score of 10.
# Restarting. 8,792,756 board positions searched, best score 4.  Loop: 2,580.
# Search initialized with score of: 30.
# Search ended with best score of 14.
# Restarting. 8,808,447 board positions searched, best score 4.  Loop: 2,584.
# Search initialized with score of: 34.
# Search ended with best score of 10.
# Restarting. 8,826,978 board positions searched, best score 4.  Loop: 2,590.
# Search initialized with score of: 26.
# Search ended with best score of 10.
# Restarting. 8,842,565 board positions searched, best score 4.  Loop: 2,594.
# Search initialized with score of: 28.
# Search ended with best score of 8.
# Restarting. 8,860,992 board positions searched, best score 4.  Loop: 2,600.
# Search initialized with score of: 40.
# Search ended with best score of 12.
# Restarting. 8,882,051 board positions searched, best score 4.  Loop: 2,605.
# Search initialized with score of: 30.
# Search ended with best score of 10.
# Restarting. 8,899,135 board positions searched, best score 4.  Loop: 2,611.
# Search initialized with score of: 28.
# Search ended with best score of 10.
# Restarting. 8,913,429 board positions searched, best score 4.  Loop: 2,615.
# Search initialized with score of: 32.
# Search ended with best score of 8.
# Restarting. 8,933,253 board positions searched, best score 4.  Loop: 2,622.
# Search initialized with score of: 32.
# Search ended with best score of 6.
# Restarting. 8,955,915 board positions searched, best score 4.  Loop: 2,630.
# Search initialized with score of: 28.
# Search ended with best score of 12.
# Restarting. 8,971,604 board positions searched, best score 4.  Loop: 2,635.
# Search initialized with score of: 24.
# Search ended with best score of 12.
# Restarting. 8,987,293 board positions searched, best score 4.  Loop: 2,640.
# Search initialized with score of: 26.
# Search ended with best score of 14.
# Restarting. 9,002,880 board positions searched, best score 4.  Loop: 2,644.
# Search initialized with score of: 32.
# Search ended with best score of 10.
# Restarting. 9,019,965 board positions searched, best score 4.  Loop: 2,650.
# Search initialized with score of: 34.
# Search ended with best score of 14.
# Restarting. 9,036,946 board positions searched, best score 4.  Loop: 2,655.
# Search initialized with score of: 26.
# Search ended with best score of 4.
# Restarting. 9,055,373 board positions searched, best score 4.  Loop: 2,661.
# Search initialized with score of: 28.
# Search ended with best score of 10.
# Restarting. 9,072,303 board positions searched, best score 4.  Loop: 2,665.
# Search initialized with score of: 26.
# Search ended with best score of 8.
# Restarting. 9,092,074 board positions searched, best score 4.  Loop: 2,672.
# Search initialized with score of: 36.
# Search ended with best score of 12.
# Restarting. 9,109,156 board positions searched, best score 4.  Loop: 2,677.
# Search initialized with score of: 30.
# Search ended with best score of 16.
# Restarting. 9,122,055 board positions searched, best score 4.  Loop: 2,680.
# Search initialized with score of: 30.
# Search ended with best score of 10.
# Restarting. 9,140,480 board positions searched, best score 4.  Loop: 2,686.
# Search initialized with score of: 16.
# Search ended with best score of 8.
# Restarting. 9,153,379 board positions searched, best score 4.  Loop: 2,689.
# Search initialized with score of: 24.
# Search ended with best score of 10.
# Restarting. 9,167,673 board positions searched, best score 4.  Loop: 2,693.
# Search initialized with score of: 30.
# Search ended with best score of 6.
# Restarting. 9,184,863 board positions searched, best score 4.  Loop: 2,698.
# Search initialized with score of: 30.
# Search ended with best score of 10.
# Restarting. 9,201,948 board positions searched, best score 4.  Loop: 2,703.
# Search initialized with score of: 34.
# Search ended with best score of 12.
# Restarting. 9,220,428 board positions searched, best score 4.  Loop: 2,708.
# Search initialized with score of: 34.
# Search ended with best score of 12.
# Restarting. 9,237,409 board positions searched, best score 4.  Loop: 2,713.
# Search initialized with score of: 22.
# Search ended with best score of 8.
# Restarting. 9,253,046 board positions searched, best score 4.  Loop: 2,717.
# Search initialized with score of: 28.
# Search ended with best score of 16.
# Restarting. 9,267,340 board positions searched, best score 4.  Loop: 2,721.
# Search initialized with score of: 28.
# Search ended with best score of 16.
# Restarting. 9,283,029 board positions searched, best score 4.  Loop: 2,725.
# Search initialized with score of: 34.
# Search ended with best score of 10.
# Restarting. 9,300,010 board positions searched, best score 4.  Loop: 2,730.
# Search initialized with score of: 20.
# Search ended with best score of 10.
# Restarting. 9,314,304 board positions searched, best score 4.  Loop: 2,734.
# Search initialized with score of: 26.
# Search ended with best score of 10.
# Restarting. 9,329,943 board positions searched, best score 4.  Loop: 2,738.
# Search initialized with score of: 26.
# Search ended with best score of 10.
# Restarting. 9,342,842 board positions searched, best score 4.  Loop: 2,741.
# Search initialized with score of: 30.
# Search ended with best score of 10.
# Restarting. 9,358,479 board positions searched, best score 4.  Loop: 2,745.
# Search initialized with score of: 38.
# Search ended with best score of 8.
# Restarting. 9,379,690 board positions searched, best score 4.  Loop: 2,752.
# Search initialized with score of: 20.
# Search ended with best score of 6.
# Restarting. 9,393,984 board positions searched, best score 4.  Loop: 2,756.
# Search initialized with score of: 30.
# Search ended with best score of 12.
# Restarting. 9,408,278 board positions searched, best score 4.  Loop: 2,760.
# Search initialized with score of: 26.
# Search ended with best score of 12.
# Restarting. 9,423,915 board positions searched, best score 4.  Loop: 2,764.
# Search initialized with score of: 26.
# Search ended with best score of 10.
# Restarting. 9,439,605 board positions searched, best score 4.  Loop: 2,768.
# Search initialized with score of: 32.
# Search ended with best score of 12.
# Restarting. 9,456,637 board positions searched, best score 4.  Loop: 2,773.
# Search initialized with score of: 26.
# Search ended with best score of 6.
# Restarting. 9,477,907 board positions searched, best score 4.  Loop: 2,780.
# Search initialized with score of: 28.
# Search ended with best score of 12.
# Restarting. 9,493,596 board positions searched, best score 4.  Loop: 2,785.
# Search initialized with score of: 28.
# Search ended with best score of 12.
# Restarting. 9,509,283 board positions searched, best score 4.  Loop: 2,789.
# Search initialized with score of: 28.
# Search ended with best score of 14.
# Restarting. 9,523,630 board positions searched, best score 4.  Loop: 2,793.
# Search initialized with score of: 32.
# Search ended with best score of 10.
# Restarting. 9,543,558 board positions searched, best score 4.  Loop: 2,801.
# Search initialized with score of: 28.
# Search ended with best score of 10.
# Restarting. 9,560,539 board positions searched, best score 4.  Loop: 2,806.
# Search initialized with score of: 24.
# Search ended with best score of 14.
# Restarting. 9,573,438 board positions searched, best score 4.  Loop: 2,809.
# Search initialized with score of: 34.
# Search ended with best score of 6.
# Restarting. 9,594,501 board positions searched, best score 4.  Loop: 2,816.
# Search initialized with score of: 30.
# Search ended with best score of 18.
# Restarting. 9,610,088 board positions searched, best score 4.  Loop: 2,820.
# Search initialized with score of: 32.
# Search ended with best score of 14.
# Restarting. 9,625,725 board positions searched, best score 4.  Loop: 2,824.
# Search initialized with score of: 26.
# Search ended with best score of 18.
# Restarting. 9,637,228 board positions searched, best score 4.  Loop: 2,826.
# Search initialized with score of: 30.
# Search ended with best score of 12.
# Restarting. 9,652,865 board positions searched, best score 4.  Loop: 2,830.
# Search initialized with score of: 24.
# Search ended with best score of 10.
# Restarting. 9,668,452 board positions searched, best score 4.  Loop: 2,834.
# Search initialized with score of: 36.
# Search ended with best score of 12.
# Restarting. 9,684,141 board positions searched, best score 4.  Loop: 2,839.
# Search initialized with score of: 38.
# Search ended with best score of 12.
# Restarting. 9,702,569 board positions searched, best score 4.  Loop: 2,844.
# Search initialized with score of: 36.
# Search ended with best score of 10.
# Restarting. 9,722,240 board positions searched, best score 4.  Loop: 2,850.
# Search initialized with score of: 20.
# Search ended with best score of 16.
# Restarting. 9,733,743 board positions searched, best score 4.  Loop: 2,852.
# Search initialized with score of: 28.
# Search ended with best score of 14.
# Restarting. 9,749,432 board positions searched, best score 4.  Loop: 2,856.
# Search initialized with score of: 30.
# Search ended with best score of 8.
# Restarting. 9,767,809 board positions searched, best score 4.  Loop: 2,862.
# Search initialized with score of: 26.
# Search ended with best score of 12.
# Restarting. 9,782,103 board positions searched, best score 4.  Loop: 2,865.
# Search initialized with score of: 24.
# Search ended with best score of 10.
# Restarting. 9,797,792 board positions searched, best score 4.  Loop: 2,870.
# Search initialized with score of: 28.
# Search ended with best score of 18.
# Restarting. 9,810,691 board positions searched, best score 4.  Loop: 2,873.
# Search initialized with score of: 22.
# Search ended with best score of 14.
# Restarting. 9,824,934 board positions searched, best score 4.  Loop: 2,876.
# Search initialized with score of: 32.
# Search ended with best score of 16.
# Restarting. 9,840,470 board positions searched, best score 4.  Loop: 2,879.
# Search initialized with score of: 32.
# Search ended with best score of 4.
# Restarting. 9,861,687 board positions searched, best score 4.  Loop: 2,887.
# Search initialized with score of: 26.
# Search ended with best score of 12.
# Restarting. 9,875,930 board positions searched, best score 4.  Loop: 2,890.
# Search initialized with score of: 30.
# Search ended with best score of 8.
# Restarting. 9,895,749 board positions searched, best score 4.  Loop: 2,896.
# Search initialized with score of: 26.
# Search ended with best score of 10.
# Restarting. 9,912,730 board positions searched, best score 4.  Loop: 2,901.
# Search initialized with score of: 32.
# Search ended with best score of 12.
# Restarting. 9,931,055 board positions searched, best score 4.  Loop: 2,906.
# Search initialized with score of: 26.
# Search ended with best score of 10.
# Restarting. 9,949,431 board positions searched, best score 4.  Loop: 2,912.
# Search initialized with score of: 28.
# Search ended with best score of 20.
# Restarting. 9,960,934 board positions searched, best score 4.  Loop: 2,914.
# Search initialized with score of: 32.
# Search ended with best score of 10.
# Restarting. 9,980,702 board positions searched, best score 4.  Loop: 2,919.
# Search initialized with score of: 26.
# Search ended with best score of 8.
# Restarting. 9,997,734 board positions searched, best score 4.  Loop: 2,924.
# Search initialized with score of: 26.
# Search ended with best score of 10.
# Restarting. 10,012,028 board positions searched, best score 4.  Loop: 2,928.
# Search initialized with score of: 34.
# Search ended with best score of 8.
# Restarting. 10,031,798 board positions searched, best score 4.  Loop: 2,934.
# Search initialized with score of: 30.
# Search ended with best score of 8.
# Restarting. 10,051,667 board positions searched, best score 4.  Loop: 2,941.
# Search initialized with score of: 30.
# Search ended with best score of 12.
# Restarting. 10,067,357 board positions searched, best score 4.  Loop: 2,945.
# Search initialized with score of: 28.
# Search ended with best score of 10.
# Restarting. 10,084,494 board positions searched, best score 4.  Loop: 2,951.
# Search initialized with score of: 26.
# Search ended with best score of 12.
# Restarting. 10,100,183 board positions searched, best score 4.  Loop: 2,955.
# Search initialized with score of: 24.
# Search ended with best score of 4.
# Restarting. 10,115,872 board positions searched, best score 4.  Loop: 2,960.
# Search initialized with score of: 22.
# Search ended with best score of 6.
# Restarting. 10,132,956 board positions searched, best score 4.  Loop: 2,966.
# Search initialized with score of: 30.
# Search ended with best score of 10.
# Restarting. 10,154,020 board positions searched, best score 4.  Loop: 2,972.
# Search initialized with score of: 28.
