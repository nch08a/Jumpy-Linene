# %%
import puzzlerepresentation as P

# %%
import numpy as np

# %%
history = {}

# %%
def addChromosomeToHistory(C):
    history[C.tostring()] = 5000

# %%
h = (6,0)
null_C = np.zeros([10,3],dtype=np.int8)
if h:
    null_C[-1] = [h[0], h[1], 0]
addChromosomeToHistory(null_C)

# %%
def buildRandomChromosome(hole=None):
    C = np.random.randint(0, 7, size=(10,3), dtype=np.int8)
    C[:,-1] = np.random.randint(0,4, size=10, dtype=np.int8)
    if hole:
        C[-1] = [hole[0], hole[1], 0]
    if C.tostring() in history:
        return buildRandomChromosome(hole=hole)
    addChromosomeToHistory(C)
    return C

# %% [raw]
# def buildRandomChromosome(hole=None):
#     C = np.random.randint(0, 7, size=(10,3), dtype=np.int8)
#     C[:,-1] = np.random.randint(0,4, size=10, dtype=np.int8)
#     if hole:
#         C[-1] = [hole[0], hole[1], 0]
#     addChromosomeToHistory(C, history)
#     return C

# %%
h = (6,0)

# %%
pieces = P.pieces + [P.Piece('black',[[0,0]])]

# %%
def score(C):
    if history[C.tostring()] != 5000:
        return history[C.tostring()]
    A = np.zeros([7,7],dtype=np.int8)
    #pieces = P.pieces + [P.Piece('black',[[0,0]])]
    for i in range(10):
        for unit in pieces[i].rot_list(C[i,2]):
            x = C[i][0] + unit[0]
            y = C[i][1] + unit[1]
            if (min(x,y) < 0) or (max(x,y) > 6):
                return np.infty
            A[x][y] += 1
    #print(np.abs(A-1).sum())
    #print(A)
    s = np.abs(np.square(A-1)).sum()
    history[C.tostring()] = s
    return s

# %%
def rebuildChromosome(C, hole=None):
    C = C.reshape(10,3)
    
    C[:,:-1] = C[:,:-1] % 7
    C[:, -1] = C[:, -1] % 4
    
    return C

# %%
def stepChromosomes(C, hole=None):
    old_C = C.flatten()
    C_list = []
    iter_size = old_C.size
    if hole:
        iter_size -=3
    for x in range(iter_size):
        new_C_add = old_C.copy()
        new_C_sub = old_C.copy()
        
        new_C_add[x] += 1
        new_C_sub[x] -= 1
        
        new_C_add = rebuildChromosome(new_C_add).copy()
        new_C_sub = rebuildChromosome(new_C_sub).copy()
        
        if new_C_add.tostring() not in history:
            addChromosomeToHistory(new_C_add)
            C_list.append(new_C_add.copy())
        
        if new_C_sub.tostring() not in history:
            addChromosomeToHistory(new_C_sub)
            C_list.append(new_C_sub.copy())
        
    return C_list

# %%
C_list = [buildRandomChromosome(hole=h) for _ in range(10000)]

# %%
best_C = null_C.copy()
best_score = score(best_C)

# %%
for C in C_list:
    s = score(C)
    if s < best_score:
        best_C = C.copy()
        best_score = s
print(f'Search initialized with best score of: {best_score}.',end='')
# Out:
# Search initialized with best score of: 28.

# %%
def startSearch(hole=None):
    C_list = [buildRandomChromosome(hole=hole) for _ in range(10000)]
    best_C = null_C.copy()
    best_score = score(best_C)
    
    for C in C_list:
        s = score(C)
        if s < best_score:
            best_C = C.copy()
            best_score = s
    print(f'Search initialized with score of: {best_score}.')
    return [best_C]

# %%
best_C_list = [best_C]

# %%
i = 0

# %%
best_ever = best_score
best_chrom_ever = best_C.copy()
while(best_ever != 0):
    C_list = []
    for C in best_C_list:
        C_list = C_list + stepChromosomes(C, hole=h)
    two_steps = []
    for C in C_list:
        two_steps = two_steps + stepChromosomes(C, hole=h)
    C_list = C_list + two_steps
    three_steps = []
    for C in C_list:
        three_steps = three_steps + stepChromosomes(C, hole=h)
    C_list = C_list + three_steps
    
    best_C_list = []
    if len(C_list) == 0:
        print(f'Search ended with best score of {best_score}.')
        print(f'Restarting. {len(history):,} board positions searched, best score {best_ever}.  Loop: {i:,}.')
        best_C_list = startSearch(hole=h)
        best_score=np.infty
    for C in C_list:
        s = score(C)
        if s < best_score:
            best_C_list.append(C.copy())
            best_score = s
            if best_score < best_ever:
                best_ever = best_score
                best_chrom_ever = C.copy()
                print(f'New best score found with score = {best_ever}.')
    i += 1
# Out:
# New best score found with score = 26.
# New best score found with score = 24.
# New best score found with score = 22.
# New best score found with score = 20.
# New best score found with score = 18.
# New best score found with score = 16.
# New best score found with score = 14.
# New best score found with score = 12.
# New best score found with score = 10.
# Search ended with best score of 10.
# Restarting. 117,515 board positions searched, best score 10.  Loop: 3.
# Search initialized with score of: 30.
# Search ended with best score of 10.
# Restarting. 208,512 board positions searched, best score 10.  Loop: 7.
# Search initialized with score of: 32.
# Search ended with best score of 12.
# Restarting. 272,604 board positions searched, best score 10.  Loop: 10.
# Search initialized with score of: 30.
# Search ended with best score of 10.
# Restarting. 360,876 board positions searched, best score 10.  Loop: 13.
# Search initialized with score of: 28.
# New best score found with score = 8.
# Search ended with best score of 8.
# Restarting. 475,946 board positions searched, best score 8.  Loop: 17.
# Search initialized with score of: 26.
# New best score found with score = 6.
# Search ended with best score of 6.
# Restarting. 647,533 board positions searched, best score 6.  Loop: 23.
# Search initialized with score of: 28.
# Search ended with best score of 10.
# Restarting. 792,201 board positions searched, best score 6.  Loop: 28.
# Search initialized with score of: 28.
# Search ended with best score of 10.
# Restarting. 883,351 board positions searched, best score 6.  Loop: 32.
# Search initialized with score of: 34.
# Search ended with best score of 10.
# Restarting. 1,055,329 board positions searched, best score 6.  Loop: 39.
# Search initialized with score of: 28.
# Search ended with best score of 10.
# Restarting. 1,173,437 board positions searched, best score 6.  Loop: 44.
# Search initialized with score of: 28.
# Search ended with best score of 14.
# Restarting. 1,237,580 board positions searched, best score 6.  Loop: 47.
# Search initialized with score of: 32.
# Search ended with best score of 18.
# Restarting. 1,274,859 board positions searched, best score 6.  Loop: 49.
# Search initialized with score of: 30.
# Search ended with best score of 8.
# Restarting. 1,419,834 board positions searched, best score 6.  Loop: 55.
# Search initialized with score of: 36.
# Search ended with best score of 8.
# Restarting. 1,591,356 board positions searched, best score 6.  Loop: 61.
# Search initialized with score of: 28.
# Search ended with best score of 10.
# Restarting. 1,709,258 board positions searched, best score 6.  Loop: 65.
# Search initialized with score of: 30.
# Search ended with best score of 6.
# Restarting. 1,878,545 board positions searched, best score 6.  Loop: 70.
# Search initialized with score of: 24.
# Search ended with best score of 14.
# Restarting. 1,915,824 board positions searched, best score 6.  Loop: 72.
# Search initialized with score of: 22.
# Search ended with best score of 10.
# Restarting. 2,033,884 board positions searched, best score 6.  Loop: 77.
# Search initialized with score of: 28.
# Search ended with best score of 8.
# Restarting. 2,125,034 board positions searched, best score 6.  Loop: 81.
# Search initialized with score of: 32.
# Search ended with best score of 12.
# Restarting. 2,213,305 board positions searched, best score 6.  Loop: 84.
# Search initialized with score of: 28.
# Search ended with best score of 10.
# Restarting. 2,304,302 board positions searched, best score 6.  Loop: 88.
# Search initialized with score of: 28.
# Search ended with best score of 8.
# Restarting. 2,395,248 board positions searched, best score 6.  Loop: 92.
# Search initialized with score of: 30.
# New best score found with score = 4.
# Search ended with best score of 4.
# Restarting. 2,539,821 board positions searched, best score 4.  Loop: 97.
# Search initialized with score of: 20.
# Search ended with best score of 8.
# Restarting. 2,604,015 board positions searched, best score 4.  Loop: 100.
# Search initialized with score of: 30.
# Search ended with best score of 10.
# Restarting. 2,694,917 board positions searched, best score 4.  Loop: 104.
# Search initialized with score of: 36.
# Search ended with best score of 10.
# Restarting. 2,836,751 board positions searched, best score 4.  Loop: 109.
# Search initialized with score of: 32.
# Search ended with best score of 8.
# Restarting. 2,954,961 board positions searched, best score 4.  Loop: 114.
# Search initialized with score of: 22.
# Search ended with best score of 12.
# Restarting. 3,045,623 board positions searched, best score 4.  Loop: 117.
# Search initialized with score of: 38.
# Search ended with best score of 8.
# Restarting. 3,187,598 board positions searched, best score 4.  Loop: 122.
# Search initialized with score of: 26.
# Search ended with best score of 8.
# Restarting. 3,278,493 board positions searched, best score 4.  Loop: 126.
# Search initialized with score of: 30.
# Search ended with best score of 10.
# Restarting. 3,393,325 board positions searched, best score 4.  Loop: 130.
# Search initialized with score of: 24.
# Search ended with best score of 14.
# Restarting. 3,430,604 board positions searched, best score 4.  Loop: 132.
# Search initialized with score of: 32.
# Search ended with best score of 10.
# Restarting. 3,548,506 board positions searched, best score 4.  Loop: 137.
# Search initialized with score of: 30.
# Search ended with best score of 8.
# Restarting. 3,666,466 board positions searched, best score 4.  Loop: 142.
# Search initialized with score of: 34.
# Search ended with best score of 10.
# Restarting. 3,784,164 board positions searched, best score 4.  Loop: 147.
# Search initialized with score of: 24.
# Search ended with best score of 8.
# Restarting. 3,875,212 board positions searched, best score 4.  Loop: 151.
# Search initialized with score of: 30.
# Search ended with best score of 8.
# Restarting. 3,990,434 board positions searched, best score 4.  Loop: 155.
# Search initialized with score of: 32.
# Search ended with best score of 10.
# Restarting. 4,107,957 board positions searched, best score 4.  Loop: 159.
# Search initialized with score of: 28.
# Search ended with best score of 6.
# Restarting. 4,303,907 board positions searched, best score 4.  Loop: 166.
# Search initialized with score of: 26.
# Search ended with best score of 6.
# Restarting. 4,448,717 board positions searched, best score 4.  Loop: 172.
# Search initialized with score of: 30.
# Search ended with best score of 10.
# Restarting. 4,563,787 board positions searched, best score 4.  Loop: 176.
# Search initialized with score of: 34.
# Search ended with best score of 12.
# Restarting. 4,654,784 board positions searched, best score 4.  Loop: 180.
# Search initialized with score of: 32.
# Search ended with best score of 14.
# Restarting. 4,743,405 board positions searched, best score 4.  Loop: 183.
# Search initialized with score of: 32.
# Search ended with best score of 10.
# Restarting. 4,860,537 board positions searched, best score 4.  Loop: 187.
# Search initialized with score of: 26.
# Search ended with best score of 12.
# Restarting. 4,924,830 board positions searched, best score 4.  Loop: 190.
# Search initialized with score of: 22.
# Search ended with best score of 12.
# Restarting. 4,962,109 board positions searched, best score 4.  Loop: 192.
# Search initialized with score of: 28.
# Search ended with best score of 16.
# Restarting. 5,026,252 board positions searched, best score 4.  Loop: 195.
# Search initialized with score of: 26.
# Search ended with best score of 8.
# Restarting. 5,144,064 board positions searched, best score 4.  Loop: 199.
# Search initialized with score of: 32.
# Search ended with best score of 12.
# Restarting. 5,235,019 board positions searched, best score 4.  Loop: 202.
# Search initialized with score of: 30.
# Search ended with best score of 8.
# Restarting. 5,376,850 board positions searched, best score 4.  Loop: 207.
# Search initialized with score of: 34.
# Search ended with best score of 8.
# Restarting. 5,521,669 board positions searched, best score 4.  Loop: 212.
# Search initialized with score of: 34.
# Search ended with best score of 8.
# Restarting. 5,637,151 board positions searched, best score 4.  Loop: 216.
# Search initialized with score of: 30.
# Search ended with best score of 12.
# Restarting. 5,727,813 board positions searched, best score 4.  Loop: 219.
# Search initialized with score of: 24.
# Search ended with best score of 6.
# Restarting. 5,845,613 board positions searched, best score 4.  Loop: 224.
# Search initialized with score of: 30.
# Search ended with best score of 10.
# Restarting. 5,960,546 board positions searched, best score 4.  Loop: 228.
# Search initialized with score of: 24.
# Search ended with best score of 10.
# Restarting. 6,024,689 board positions searched, best score 4.  Loop: 231.
# Search initialized with score of: 32.
# Search ended with best score of 10.
# Restarting. 6,115,686 board positions searched, best score 4.  Loop: 235.
# Search initialized with score of: 30.
# Search ended with best score of 8.
# Restarting. 6,257,365 board positions searched, best score 4.  Loop: 240.
# Search initialized with score of: 28.
# Search ended with best score of 8.
# Restarting. 6,348,567 board positions searched, best score 4.  Loop: 244.
# Search initialized with score of: 24.
# Search ended with best score of 8.
# Restarting. 6,412,659 board positions searched, best score 4.  Loop: 247.
# Search initialized with score of: 34.
# Search ended with best score of 12.
# Restarting. 6,503,370 board positions searched, best score 4.  Loop: 250.
# Search initialized with score of: 26.
# Search ended with best score of 12.
# Restarting. 6,567,462 board positions searched, best score 4.  Loop: 253.
# Search initialized with score of: 32.
# Search ended with best score of 10.
# Restarting. 6,709,347 board positions searched, best score 4.  Loop: 258.
# Search initialized with score of: 26.
# Search ended with best score of 12.
# Restarting. 6,773,439 board positions searched, best score 4.  Loop: 261.
# Search initialized with score of: 24.
# Search ended with best score of 8.
# Restarting. 6,888,866 board positions searched, best score 4.  Loop: 265.
# Search initialized with score of: 24.
# Search ended with best score of 6.
# Restarting. 7,006,587 board positions searched, best score 4.  Loop: 269.
# Search initialized with score of: 26.
# Search ended with best score of 6.
# Restarting. 7,124,159 board positions searched, best score 4.  Loop: 273.
# Search initialized with score of: 32.
# Search ended with best score of 8.
# Restarting. 7,266,285 board positions searched, best score 4.  Loop: 277.
# Search initialized with score of: 36.
# Search ended with best score of 8.
# Restarting. 7,410,694 board positions searched, best score 4.  Loop: 282.
# Search initialized with score of: 24.
# Search ended with best score of 8.
# Restarting. 7,475,039 board positions searched, best score 4.  Loop: 285.
# Search initialized with score of: 26.
# Search ended with best score of 8.
# Restarting. 7,566,138 board positions searched, best score 4.  Loop: 289.
# Search initialized with score of: 38.
# Search ended with best score of 12.
# Restarting. 7,657,186 board positions searched, best score 4.  Loop: 293.
# Search initialized with score of: 26.
# Search ended with best score of 8.
# Restarting. 7,774,993 board positions searched, best score 4.  Loop: 297.
# Search initialized with score of: 24.
# Search ended with best score of 6.
# Restarting. 7,919,749 board positions searched, best score 4.  Loop: 302.
# Search initialized with score of: 30.
# Search ended with best score of 6.
# Restarting. 8,010,906 board positions searched, best score 4.  Loop: 306.
# Search initialized with score of: 30.
# Search ended with best score of 10.
# Restarting. 8,128,512 board positions searched, best score 4.  Loop: 310.
# Search initialized with score of: 30.
# Search ended with best score of 12.
# Restarting. 8,243,633 board positions searched, best score 4.  Loop: 314.
# Search initialized with score of: 26.
# Search ended with best score of 12.
# Restarting. 8,307,725 board positions searched, best score 4.  Loop: 317.
# Search initialized with score of: 26.
# Search ended with best score of 8.
# Restarting. 8,398,824 board positions searched, best score 4.  Loop: 321.
# Search initialized with score of: 32.
# Search ended with best score of 8.
# Restarting. 8,489,770 board positions searched, best score 4.  Loop: 325.
# Search initialized with score of: 24.
# Search ended with best score of 16.
# Restarting. 8,527,049 board positions searched, best score 4.  Loop: 327.
# Search initialized with score of: 28.
# Search ended with best score of 12.
# Restarting. 8,642,382 board positions searched, best score 4.  Loop: 330.
# Search initialized with score of: 34.
# Search ended with best score of 8.
# Restarting. 8,759,950 board positions searched, best score 4.  Loop: 334.
# Search initialized with score of: 28.
# Search ended with best score of 14.
# Restarting. 8,824,042 board positions searched, best score 4.  Loop: 337.
# Search initialized with score of: 26.
# Search ended with best score of 12.
# Restarting. 8,888,185 board positions searched, best score 4.  Loop: 340.
# Search initialized with score of: 30.
# Search ended with best score of 12.
# Restarting. 8,952,581 board positions searched, best score 4.  Loop: 343.
# Search initialized with score of: 32.
# Search ended with best score of 8.
# Restarting. 9,070,144 board positions searched, best score 4.  Loop: 347.
# Search initialized with score of: 30.
# Search ended with best score of 10.
# Restarting. 9,161,243 board positions searched, best score 4.  Loop: 351.
# Search initialized with score of: 30.
# Search ended with best score of 10.
# Restarting. 9,225,386 board positions searched, best score 4.  Loop: 354.
# Search initialized with score of: 26.
# Search ended with best score of 10.
# Restarting. 9,340,507 board positions searched, best score 4.  Loop: 358.
# Search initialized with score of: 30.
# Search ended with best score of 12.
# Restarting. 9,404,650 board positions searched, best score 4.  Loop: 361.
# Search initialized with score of: 30.
# Search ended with best score of 10.
# Restarting. 9,468,793 board positions searched, best score 4.  Loop: 364.
# Search initialized with score of: 28.
# Search ended with best score of 12.
# Restarting. 9,586,450 board positions searched, best score 4.  Loop: 368.
# Search initialized with score of: 24.
# Search ended with best score of 10.
# Restarting. 9,650,593 board positions searched, best score 4.  Loop: 371.
# Search initialized with score of: 26.
# Search ended with best score of 12.
# Restarting. 9,738,864 board positions searched, best score 4.  Loop: 374.
# Search initialized with score of: 22.
# Search ended with best score of 12.
# Restarting. 9,803,007 board positions searched, best score 4.  Loop: 377.
# Search initialized with score of: 26.
# Search ended with best score of 10.
# Restarting. 9,867,150 board positions searched, best score 4.  Loop: 380.
# Search initialized with score of: 36.
# Search ended with best score of 12.
# Restarting. 9,958,457 board positions searched, best score 4.  Loop: 384.
# Search initialized with score of: 30.
# Search ended with best score of 8.
# Restarting. 10,130,325 board positions searched, best score 4.  Loop: 391.
# Search initialized with score of: 28.
# Search ended with best score of 8.
# Restarting. 10,275,135 board positions searched, best score 4.  Loop: 396.
# Search initialized with score of: 28.
# Search ended with best score of 8.
# Restarting. 10,419,860 board positions searched, best score 4.  Loop: 402.
# Search initialized with score of: 24.
# Search ended with best score of 10.
# Restarting. 10,483,952 board positions searched, best score 4.  Loop: 405.
# Search initialized with score of: 28.
# Search ended with best score of 10.
# Restarting. 10,601,621 board positions searched, best score 4.  Loop: 409.
# Search initialized with score of: 26.
# Search ended with best score of 10.
# Restarting. 10,689,993 board positions searched, best score 4.  Loop: 412.
# Search initialized with score of: 32.
# Search ended with best score of 8.
# Restarting. 10,754,136 board positions searched, best score 4.  Loop: 415.
# Search initialized with score of: 34.
# Search ended with best score of 12.
# Restarting. 10,871,706 board positions searched, best score 4.  Loop: 419.
# Search initialized with score of: 36.
# Search ended with best score of 10.
# Restarting. 11,016,724 board positions searched, best score 4.  Loop: 425.
# Search initialized with score of: 26.
# Search ended with best score of 14.
# Restarting. 11,080,816 board positions searched, best score 4.  Loop: 428.
# Search initialized with score of: 28.
# Search ended with best score of 10.
# Restarting. 11,195,894 board positions searched, best score 4.  Loop: 432.
# Search initialized with score of: 34.
# Search ended with best score of 14.
# Restarting. 11,284,367 board positions searched, best score 4.  Loop: 435.
# Search initialized with score of: 30.
# Search ended with best score of 10.
# Restarting. 11,399,351 board positions searched, best score 4.  Loop: 439.
# Search initialized with score of: 28.
# Search ended with best score of 14.
# Restarting. 11,436,630 board positions searched, best score 4.  Loop: 441.
# Search initialized with score of: 30.
# Search ended with best score of 10.
# Restarting. 11,527,525 board positions searched, best score 4.  Loop: 445.
# Search initialized with score of: 26.
# Search ended with best score of 12.
# Restarting. 11,618,471 board positions searched, best score 4.  Loop: 449.
# Search initialized with score of: 34.
# Search ended with best score of 10.
# Restarting. 11,736,632 board positions searched, best score 4.  Loop: 453.
# Search initialized with score of: 28.
# Search ended with best score of 8.
# Restarting. 11,854,585 board positions searched, best score 4.  Loop: 458.
# Search initialized with score of: 20.
# Search ended with best score of 16.
# Restarting. 11,891,864 board positions searched, best score 4.  Loop: 460.
# Search initialized with score of: 30.
# Search ended with best score of 8.
# Restarting. 12,009,382 board positions searched, best score 4.  Loop: 464.
# Search initialized with score of: 30.
# Search ended with best score of 10.
# Restarting. 12,100,583 board positions searched, best score 4.  Loop: 468.
# Search initialized with score of: 24.
# Search ended with best score of 6.
# Restarting. 12,191,682 board positions searched, best score 4.  Loop: 472.
# Search initialized with score of: 24.
# Search ended with best score of 8.
# Restarting. 12,309,635 board positions searched, best score 4.  Loop: 477.
# Search initialized with score of: 30.
# Search ended with best score of 12.
# Restarting. 12,373,980 board positions searched, best score 4.  Loop: 480.
# Search initialized with score of: 36.
# Search ended with best score of 10.
# Restarting. 12,545,711 board positions searched, best score 4.  Loop: 485.
# Search initialized with score of: 34.
# Search ended with best score of 6.
# Restarting. 12,663,873 board positions searched, best score 4.  Loop: 490.
# Search initialized with score of: 28.
# Search ended with best score of 8.
# Restarting. 12,754,819 board positions searched, best score 4.  Loop: 494.
# Search initialized with score of: 32.
# Search ended with best score of 10.
# Restarting. 12,870,051 board positions searched, best score 4.  Loop: 498.
# Search initialized with score of: 26.
# Search ended with best score of 8.
# Restarting. 12,961,150 board positions searched, best score 4.  Loop: 502.
# Search initialized with score of: 30.
# Search ended with best score of 14.
# Restarting. 13,025,242 board positions searched, best score 4.  Loop: 505.
# Search initialized with score of: 26.
# Search ended with best score of 8.
# Restarting. 13,116,195 board positions searched, best score 4.  Loop: 509.
# Search initialized with score of: 28.
# Search ended with best score of 8.
# Restarting. 13,231,262 board positions searched, best score 4.  Loop: 513.
# Search initialized with score of: 28.
# Search ended with best score of 12.
# Restarting. 13,348,827 board positions searched, best score 4.  Loop: 517.
# Search initialized with score of: 28.
# Search ended with best score of 10.
# Restarting. 13,439,722 board positions searched, best score 4.  Loop: 521.
# Search initialized with score of: 32.
# Search ended with best score of 8.
# Restarting. 13,557,933 board positions searched, best score 4.  Loop: 526.
# Search initialized with score of: 28.
# Search ended with best score of 8.
# Restarting. 13,649,032 board positions searched, best score 4.  Loop: 530.
# Search initialized with score of: 24.
# Search ended with best score of 8.
# Restarting. 13,739,934 board positions searched, best score 4.  Loop: 534.
# Search initialized with score of: 28.
# Search ended with best score of 10.
# Restarting. 13,830,931 board positions searched, best score 4.  Loop: 538.
# Search initialized with score of: 28.
# Search ended with best score of 10.
# Restarting. 13,946,103 board positions searched, best score 4.  Loop: 542.
# Search initialized with score of: 30.
# Search ended with best score of 4.
# Restarting. 14,090,844 board positions searched, best score 4.  Loop: 547.
# Search initialized with score of: 22.
# Search ended with best score of 10.
# Restarting. 14,181,947 board positions searched, best score 4.  Loop: 551.
# Search initialized with score of: 26.
# Search ended with best score of 8.
# Restarting. 14,272,995 board positions searched, best score 4.  Loop: 555.
# Search initialized with score of: 24.
# Search ended with best score of 8.
# Restarting. 14,364,197 board positions searched, best score 4.  Loop: 559.
# Search initialized with score of: 28.
# Search ended with best score of 10.
# Restarting. 14,479,368 board positions searched, best score 4.  Loop: 563.
# Search initialized with score of: 30.
# Search ended with best score of 10.
# Restarting. 14,570,365 board positions searched, best score 4.  Loop: 567.
# Search initialized with score of: 28.
# Search ended with best score of 6.
# Restarting. 14,715,224 board positions searched, best score 4.  Loop: 572.
# Search initialized with score of: 30.
# Search ended with best score of 10.
# Restarting. 14,803,495 board positions searched, best score 4.  Loop: 575.
# Search initialized with score of: 32.
# Search ended with best score of 10.
# Restarting. 14,918,666 board positions searched, best score 4.  Loop: 579.
# Search initialized with score of: 30.
# Search ended with best score of 10.
# Restarting. 15,033,787 board positions searched, best score 4.  Loop: 583.
# Search initialized with score of: 32.
# Search ended with best score of 12.
# Restarting. 15,124,835 board positions searched, best score 4.  Loop: 586.
# Search initialized with score of: 28.
# Search ended with best score of 8.
# Restarting. 15,242,893 board positions searched, best score 4.  Loop: 591.
# Search initialized with score of: 30.
# Search ended with best score of 8.
# Restarting. 15,358,065 board positions searched, best score 4.  Loop: 595.
# Search initialized with score of: 34.
# Search ended with best score of 6.
# Restarting. 15,502,635 board positions searched, best score 4.  Loop: 600.
# Search initialized with score of: 22.
# Search ended with best score of 8.
# Restarting. 15,591,054 board positions searched, best score 4.  Loop: 603.
# Search initialized with score of: 24.
# Search ended with best score of 10.
# Restarting. 15,655,197 board positions searched, best score 4.  Loop: 606.
# Search initialized with score of: 26.
# Search ended with best score of 8.
# Restarting. 15,719,340 board positions searched, best score 4.  Loop: 609.
# Search initialized with score of: 32.
# Search ended with best score of 10.
# Restarting. 15,834,569 board positions searched, best score 4.  Loop: 613.
# Search initialized with score of: 26.
# Search ended with best score of 10.
# Restarting. 15,952,778 board positions searched, best score 4.  Loop: 617.
# Search initialized with score of: 28.
# Search ended with best score of 8.
# Restarting. 16,070,528 board positions searched, best score 4.  Loop: 621.
# Search initialized with score of: 26.
# Search ended with best score of 8.
# Restarting. 16,188,638 board positions searched, best score 4.  Loop: 626.
# Search initialized with score of: 32.
# Search ended with best score of 12.
# Restarting. 16,279,635 board positions searched, best score 4.  Loop: 630.
# Search initialized with score of: 30.
# Search ended with best score of 14.
# Restarting. 16,343,727 board positions searched, best score 4.  Loop: 633.
# Search initialized with score of: 30.
# Search ended with best score of 6.
# Restarting. 16,485,855 board positions searched, best score 4.  Loop: 638.
# Search initialized with score of: 26.
# Search ended with best score of 6.
# Restarting. 16,603,808 board positions searched, best score 4.  Loop: 643.
# Search initialized with score of: 26.
# Search ended with best score of 10.
# Restarting. 16,668,002 board positions searched, best score 4.  Loop: 646.
# Search initialized with score of: 28.
# Search ended with best score of 10.
# Restarting. 16,783,123 board positions searched, best score 4.  Loop: 650.
# Search initialized with score of: 32.
# Search ended with best score of 14.
# Restarting. 16,847,266 board positions searched, best score 4.  Loop: 653.
# Search initialized with score of: 26.
# Search ended with best score of 12.
# Restarting. 16,938,212 board positions searched, best score 4.  Loop: 657.
# Search initialized with score of: 28.
# Search ended with best score of 8.
# Restarting. 17,053,291 board positions searched, best score 4.  Loop: 661.
# Search initialized with score of: 22.
# Search ended with best score of 10.
# Restarting. 17,144,441 board positions searched, best score 4.  Loop: 665.
# Search initialized with score of: 30.
# Search ended with best score of 10.
# Restarting. 17,235,387 board positions searched, best score 4.  Loop: 668.
# Search initialized with score of: 32.
# Search ended with best score of 8.
# Restarting. 17,350,320 board positions searched, best score 4.  Loop: 672.
# Search initialized with score of: 26.
# Search ended with best score of 12.
# Restarting. 17,414,463 board positions searched, best score 4.  Loop: 675.
# Search initialized with score of: 36.
# Search ended with best score of 8.
# Restarting. 17,532,314 board positions searched, best score 4.  Loop: 680.
# Search initialized with score of: 22.
# Search ended with best score of 6.
# Restarting. 17,647,483 board positions searched, best score 4.  Loop: 684.
# Search initialized with score of: 32.
# Search ended with best score of 14.
# Restarting. 17,738,480 board positions searched, best score 4.  Loop: 687.
# Search initialized with score of: 30.
# Search ended with best score of 6.
# Restarting. 17,883,058 board positions searched, best score 4.  Loop: 692.
# Search initialized with score of: 26.
# Search ended with best score of 12.
# Restarting. 17,947,351 board positions searched, best score 4.  Loop: 695.
# Search initialized with score of: 32.
# Search ended with best score of 10.
# Restarting. 18,038,450 board positions searched, best score 4.  Loop: 699.
# Search initialized with score of: 32.
# Search ended with best score of 8.
# Restarting. 18,182,528 board positions searched, best score 4.  Loop: 704.
# Search initialized with score of: 24.
# Search ended with best score of 12.
# Restarting. 18,246,671 board positions searched, best score 4.  Loop: 707.
# Search initialized with score of: 26.
# Search ended with best score of 14.
# Restarting. 18,310,964 board positions searched, best score 4.  Loop: 710.
# Search initialized with score of: 28.
# Search ended with best score of 10.
# Restarting. 18,401,777 board positions searched, best score 4.  Loop: 713.
# Search initialized with score of: 26.
# Search ended with best score of 10.
# Restarting. 18,492,679 board positions searched, best score 4.  Loop: 717.
# Search initialized with score of: 24.
# Search ended with best score of 14.
# Restarting. 18,556,771 board positions searched, best score 4.  Loop: 720.
# Search initialized with score of: 22.
# Search ended with best score of 16.
# Restarting. 18,594,050 board positions searched, best score 4.  Loop: 722.
# Search initialized with score of: 24.
# Search ended with best score of 12.
# Restarting. 18,658,142 board positions searched, best score 4.  Loop: 725.
# Search initialized with score of: 30.
# Search ended with best score of 10.
# Restarting. 18,749,292 board positions searched, best score 4.  Loop: 729.
# Search initialized with score of: 26.
# Search ended with best score of 8.
# Restarting. 18,921,426 board positions searched, best score 4.  Loop: 735.
# Search initialized with score of: 30.
# Search ended with best score of 10.
# Restarting. 19,012,525 board positions searched, best score 4.  Loop: 739.
# Search initialized with score of: 32.
# Search ended with best score of 10.
# Restarting. 19,127,698 board positions searched, best score 4.  Loop: 743.
# Search initialized with score of: 32.
# Search ended with best score of 16.
# Restarting. 19,191,790 board positions searched, best score 4.  Loop: 746.
# Search initialized with score of: 24.
# Search ended with best score of 12.
# Restarting. 19,255,933 board positions searched, best score 4.  Loop: 749.
# Search initialized with score of: 26.
# Search ended with best score of 10.
# Restarting. 19,373,940 board positions searched, best score 4.  Loop: 754.
# Search initialized with score of: 20.
# Search ended with best score of 6.
# Restarting. 19,438,285 board positions searched, best score 4.  Loop: 757.
# Search initialized with score of: 26.
# Search ended with best score of 12.
# Restarting. 19,502,428 board positions searched, best score 4.  Loop: 760.
# Search initialized with score of: 32.
# Search ended with best score of 12.
# Restarting. 19,619,946 board positions searched, best score 4.  Loop: 764.
# Search initialized with score of: 28.
# Search ended with best score of 12.
# Restarting. 19,710,943 board positions searched, best score 4.  Loop: 768.
# Search initialized with score of: 32.
# Search ended with best score of 14.
# Restarting. 19,828,412 board positions searched, best score 4.  Loop: 771.
# Search initialized with score of: 28.
# Search ended with best score of 14.
# Restarting. 19,892,555 board positions searched, best score 4.  Loop: 774.
# Search initialized with score of: 30.
# Search ended with best score of 12.
# Restarting. 19,983,460 board positions searched, best score 4.  Loop: 778.
# Search initialized with score of: 24.
# Search ended with best score of 10.
# Restarting. 20,047,552 board positions searched, best score 4.  Loop: 781.
# Search initialized with score of: 26.
# Search ended with best score of 6.
# Restarting. 20,165,403 board positions searched, best score 4.  Loop: 786.
# Search initialized with score of: 28.
# Search ended with best score of 6.
# Restarting. 20,310,264 board positions searched, best score 4.  Loop: 792.
# Search initialized with score of: 24.
# Search ended with best score of 6.
# Restarting. 20,401,261 board positions searched, best score 4.  Loop: 796.
# Search initialized with score of: 28.
# Search ended with best score of 14.
# Restarting. 20,465,554 board positions searched, best score 4.  Loop: 799.
# Search initialized with score of: 34.
# Search ended with best score of 10.
# Restarting. 20,580,776 board positions searched, best score 4.  Loop: 803.
# Search initialized with score of: 28.
# Search ended with best score of 10.
# Restarting. 20,671,722 board positions searched, best score 4.  Loop: 807.
# Search initialized with score of: 40.
# Search ended with best score of 8.
# Restarting. 20,816,686 board positions searched, best score 4.  Loop: 813.
# Search initialized with score of: 30.
# Search ended with best score of 8.
# Restarting. 20,988,565 board positions searched, best score 4.  Loop: 820.
# Search initialized with score of: 32.
# Search ended with best score of 6.
# Restarting. 21,130,352 board positions searched, best score 4.  Loop: 825.
# Search initialized with score of: 22.
# Search ended with best score of 10.
# Restarting. 21,194,495 board positions searched, best score 4.  Loop: 828.
# Search initialized with score of: 28.
# Search ended with best score of 10.
# Restarting. 21,285,390 board positions searched, best score 4.  Loop: 832.
# Search initialized with score of: 30.
# Search ended with best score of 8.
# Restarting. 21,376,150 board positions searched, best score 4.  Loop: 835.
# Search initialized with score of: 30.
# Search ended with best score of 12.
# Restarting. 21,440,293 board positions searched, best score 4.  Loop: 838.
# Search initialized with score of: 24.
# Search ended with best score of 8.
# Restarting. 21,531,290 board positions searched, best score 4.  Loop: 842.
# Search initialized with score of: 30.
# Search ended with best score of 12.
# Restarting. 21,622,389 board positions searched, best score 4.  Loop: 846.
# Search initialized with score of: 26.
# Search ended with best score of 12.
# Restarting. 21,686,481 board positions searched, best score 4.  Loop: 849.
# Search initialized with score of: 26.
# Search ended with best score of 10.
# Restarting. 21,777,376 board positions searched, best score 4.  Loop: 853.
# Search initialized with score of: 34.
# Search ended with best score of 4.
# Restarting. 21,946,574 board positions searched, best score 4.  Loop: 859.
# Search initialized with score of: 38.
# Search ended with best score of 4.
# Restarting. 22,142,772 board positions searched, best score 4.  Loop: 866.
# Search initialized with score of: 28.
# Search ended with best score of 10.
# Restarting. 22,206,864 board positions searched, best score 4.  Loop: 869.
# Search initialized with score of: 24.
# Search ended with best score of 8.
# Restarting. 22,324,664 board positions searched, best score 4.  Loop: 874.
# Search initialized with score of: 34.
# Search ended with best score of 12.
# Restarting. 22,439,846 board positions searched, best score 4.  Loop: 878.
# Search initialized with score of: 24.
# Search ended with best score of 6.
# Restarting. 22,557,604 board positions searched, best score 4.  Loop: 883.
# Search initialized with score of: 22.
# Search ended with best score of 10.
# Restarting. 22,648,805 board positions searched, best score 4.  Loop: 887.
# Search initialized with score of: 28.
# Search ended with best score of 6.
# Restarting. 22,763,839 board positions searched, best score 4.  Loop: 891.
# Search initialized with score of: 38.
# Search ended with best score of 12.
# Restarting. 22,908,810 board positions searched, best score 4.  Loop: 896.
# Search initialized with score of: 30.
# Search ended with best score of 12.
# Restarting. 22,999,705 board positions searched, best score 4.  Loop: 900.
# Search initialized with score of: 30.
# Search ended with best score of 10.
# Restarting. 23,091,007 board positions searched, best score 4.  Loop: 904.
# Search initialized with score of: 26.
# Search ended with best score of 8.
# Restarting. 23,208,964 board positions searched, best score 4.  Loop: 909.
# Search initialized with score of: 34.
# Search ended with best score of 8.
# Restarting. 23,299,961 board positions searched, best score 4.  Loop: 913.
# Search initialized with score of: 30.
# Search ended with best score of 14.
# Restarting. 23,364,254 board positions searched, best score 4.  Loop: 916.
# Search initialized with score of: 32.
# Search ended with best score of 10.
# Restarting. 23,479,779 board positions searched, best score 4.  Loop: 920.
# Search initialized with score of: 32.
# Search ended with best score of 4.
# Restarting. 23,594,863 board positions searched, best score 4.  Loop: 924.
# Search initialized with score of: 32.
# Search ended with best score of 14.
# Restarting. 23,683,235 board positions searched, best score 4.  Loop: 927.
# Search initialized with score of: 30.
# Search ended with best score of 10.
# Restarting. 23,774,130 board positions searched, best score 4.  Loop: 931.
# Search initialized with score of: 22.
# Search ended with best score of 12.
# Restarting. 23,838,324 board positions searched, best score 4.  Loop: 934.
# Search initialized with score of: 30.
# Search ended with best score of 10.
# Restarting. 23,929,321 board positions searched, best score 4.  Loop: 938.
# Search initialized with score of: 32.
# Search ended with best score of 8.
# Restarting. 24,074,038 board positions searched, best score 4.  Loop: 943.
# Search initialized with score of: 34.
# Search ended with best score of 8.
# Restarting. 24,219,005 board positions searched, best score 4.  Loop: 947.
# Search initialized with score of: 22.
# Search ended with best score of 6.
# Restarting. 24,336,907 board positions searched, best score 4.  Loop: 951.
# Search initialized with score of: 34.
# Search ended with best score of 18.
# Restarting. 24,401,200 board positions searched, best score 4.  Loop: 954.
# Search initialized with score of: 24.
# Search ended with best score of 8.
# Restarting. 24,492,102 board positions searched, best score 4.  Loop: 958.
# Search initialized with score of: 20.
# Search ended with best score of 10.
# Restarting. 24,556,395 board positions searched, best score 4.  Loop: 961.
# Search initialized with score of: 28.
# Search ended with best score of 10.
# Restarting. 24,674,153 board positions searched, best score 4.  Loop: 965.
# Search initialized with score of: 28.
# Search ended with best score of 8.
# Restarting. 24,791,727 board positions searched, best score 4.  Loop: 969.
# Search initialized with score of: 30.
# Search ended with best score of 16.
# Restarting. 24,855,819 board positions searched, best score 4.  Loop: 972.
# Search initialized with score of: 32.
# Search ended with best score of 8.
# Restarting. 24,973,877 board positions searched, best score 4.  Loop: 977.
# Search initialized with score of: 30.
# Search ended with best score of 12.
# Restarting. 25,064,588 board positions searched, best score 4.  Loop: 980.
# Search initialized with score of: 32.
# Search ended with best score of 18.
# Restarting. 25,128,731 board positions searched, best score 4.  Loop: 983.
# Search initialized with score of: 36.
# Search ended with best score of 8.
# Restarting. 25,246,738 board positions searched, best score 4.  Loop: 988.
# Search initialized with score of: 32.
# Search ended with best score of 10.
# Restarting. 25,415,474 board positions searched, best score 4.  Loop: 993.
# Search initialized with score of: 26.
# Search ended with best score of 8.
# Restarting. 25,533,274 board positions searched, best score 4.  Loop: 998.
# Search initialized with score of: 24.
# Search ended with best score of 8.
# Restarting. 25,651,279 board positions searched, best score 4.  Loop: 1,003.
# Search initialized with score of: 22.
# Search ended with best score of 8.
# Restarting. 25,769,286 board positions searched, best score 4.  Loop: 1,008.
# Search initialized with score of: 28.
# Search ended with best score of 12.
# Restarting. 25,860,232 board positions searched, best score 4.  Loop: 1,011.
# Search initialized with score of: 26.
# Search ended with best score of 10.
# Restarting. 25,978,291 board positions searched, best score 4.  Loop: 1,016.
# Search initialized with score of: 28.
# Search ended with best score of 10.
# Restarting. 26,069,237 board positions searched, best score 4.  Loop: 1,020.
# Search initialized with score of: 30.
# Search ended with best score of 8.
# Restarting. 26,213,222 board positions searched, best score 4.  Loop: 1,025.
# Search initialized with score of: 26.
# Search ended with best score of 10.
# Restarting. 26,277,314 board positions searched, best score 4.  Loop: 1,028.
# Search initialized with score of: 32.
# Search ended with best score of 12.
# Restarting. 26,395,114 board positions searched, best score 4.  Loop: 1,032.
# Search initialized with score of: 32.
# Search ended with best score of 6.
# Restarting. 26,513,220 board positions searched, best score 4.  Loop: 1,036.
# Search initialized with score of: 36.
# Search ended with best score of 8.
# Restarting. 26,655,187 board positions searched, best score 4.  Loop: 1,041.
# Search initialized with score of: 30.
# Search ended with best score of 14.
# Restarting. 26,719,330 board positions searched, best score 4.  Loop: 1,044.
# Search initialized with score of: 32.
# Search ended with best score of 6.
# Restarting. 26,918,073 board positions searched, best score 4.  Loop: 1,051.
# Search initialized with score of: 28.
# Search ended with best score of 8.
# Restarting. 27,063,452 board positions searched, best score 4.  Loop: 1,057.
# Search initialized with score of: 32.
# Search ended with best score of 8.
# Restarting. 27,181,252 board positions searched, best score 4.  Loop: 1,062.
# Search initialized with score of: 30.
# Search ended with best score of 8.
# Restarting. 27,323,238 board positions searched, best score 4.  Loop: 1,067.
# Search initialized with score of: 22.
# Search ended with best score of 6.
# Restarting. 27,414,193 board positions searched, best score 4.  Loop: 1,070.
# Search initialized with score of: 28.
# Search ended with best score of 16.
# Restarting. 27,478,336 board positions searched, best score 4.  Loop: 1,073.
# Search initialized with score of: 24.
# Search ended with best score of 4.
# Restarting. 27,623,399 board positions searched, best score 4.  Loop: 1,079.
# Search initialized with score of: 30.
# Search ended with best score of 8.
# Restarting. 27,768,111 board positions searched, best score 4.  Loop: 1,084.
# Search initialized with score of: 24.
# Search ended with best score of 6.
# Restarting. 27,859,057 board positions searched, best score 4.  Loop: 1,088.
# Search initialized with score of: 32.
# Search ended with best score of 14.
# Restarting. 27,923,302 board positions searched, best score 4.  Loop: 1,091.
# Search initialized with score of: 34.
# Search ended with best score of 10.
# Restarting. 28,041,357 board positions searched, best score 4.  Loop: 1,095.
# Search initialized with score of: 36.
# Search ended with best score of 18.
# Restarting. 28,105,449 board positions searched, best score 4.  Loop: 1,098.
# Search initialized with score of: 26.
# Search ended with best score of 8.
# Restarting. 28,223,508 board positions searched, best score 4.  Loop: 1,102.
# Search initialized with score of: 30.
# Search ended with best score of 16.
# Restarting. 28,314,364 board positions searched, best score 4.  Loop: 1,105.
# Search initialized with score of: 24.
# Search ended with best score of 10.
# Restarting. 28,378,558 board positions searched, best score 4.  Loop: 1,108.
# Search initialized with score of: 30.
# Search ended with best score of 6.
# Restarting. 28,574,961 board positions searched, best score 4.  Loop: 1,114.
# Search initialized with score of: 30.
# Search ended with best score of 8.
# Restarting. 28,692,528 board positions searched, best score 4.  Loop: 1,118.
# Search initialized with score of: 30.
# Search ended with best score of 8.
# Restarting. 28,810,328 board positions searched, best score 4.  Loop: 1,123.
# Search initialized with score of: 32.
# Search ended with best score of 8.
# Restarting. 28,901,325 board positions searched, best score 4.  Loop: 1,127.
# Search initialized with score of: 30.
# Search ended with best score of 10.
# Restarting. 29,070,204 board positions searched, best score 4.  Loop: 1,132.
# Search initialized with score of: 26.
# Search ended with best score of 8.
# Restarting. 29,160,968 board positions searched, best score 4.  Loop: 1,135.
# Search initialized with score of: 30.
# Search ended with best score of 14.
# Restarting. 29,225,060 board positions searched, best score 4.  Loop: 1,138.
# Search initialized with score of: 34.
# Search ended with best score of 6.
# Restarting. 29,343,019 board positions searched, best score 4.  Loop: 1,142.
# Search initialized with score of: 30.
# Search ended with best score of 10.
# Restarting. 29,433,965 board positions searched, best score 4.  Loop: 1,146.
# Search initialized with score of: 28.
# Search ended with best score of 8.
# Restarting. 29,525,115 board positions searched, best score 4.  Loop: 1,150.
# Search initialized with score of: 30.
# Search ended with best score of 6.
# Restarting. 29,643,075 board positions searched, best score 4.  Loop: 1,155.
# Search initialized with score of: 24.
# Search ended with best score of 12.
# Restarting. 29,707,218 board positions searched, best score 4.  Loop: 1,158.
# Search initialized with score of: 28.
# Search ended with best score of 20.
# Restarting. 29,744,497 board positions searched, best score 4.  Loop: 1,160.
# Search initialized with score of: 24.
# Search ended with best score of 12.
# Restarting. 29,835,753 board positions searched, best score 4.  Loop: 1,163.
# Search initialized with score of: 32.
# Search ended with best score of 10.
# Restarting. 29,926,699 board positions searched, best score 4.  Loop: 1,167.
# Search initialized with score of: 32.
# Search ended with best score of 10.
# Restarting. 30,098,877 board positions searched, best score 4.  Loop: 1,173.
# Search initialized with score of: 18.
# Search ended with best score of 10.
# Restarting. 30,162,969 board positions searched, best score 4.  Loop: 1,176.
# Search initialized with score of: 30.
# Search ended with best score of 8.
# Restarting. 30,305,138 board positions searched, best score 4.  Loop: 1,180.
# Search initialized with score of: 26.
# Search ended with best score of 6.
# Restarting. 30,420,613 board positions searched, best score 4.  Loop: 1,184.
# Search initialized with score of: 26.
# Search ended with best score of 8.
# Restarting. 30,565,464 board positions searched, best score 4.  Loop: 1,189.
# Search initialized with score of: 28.
# Search ended with best score of 10.
# Restarting. 30,656,512 board positions searched, best score 4.  Loop: 1,193.
# Search initialized with score of: 24.
# Search ended with best score of 4.
# Restarting. 30,827,047 board positions searched, best score 4.  Loop: 1,199.
# Search initialized with score of: 28.
# Search ended with best score of 16.
# Restarting. 30,864,326 board positions searched, best score 4.  Loop: 1,201.
# Search initialized with score of: 30.
# Search ended with best score of 10.
# Restarting. 30,955,374 board positions searched, best score 4.  Loop: 1,205.
# Search initialized with score of: 26.
# Search ended with best score of 6.
# Restarting. 31,099,990 board positions searched, best score 4.  Loop: 1,211.
# Search initialized with score of: 38.
# Search ended with best score of 12.
# Restarting. 31,191,140 board positions searched, best score 4.  Loop: 1,215.
# Search initialized with score of: 34.
# Search ended with best score of 12.
# Restarting. 31,255,232 board positions searched, best score 4.  Loop: 1,218.
# Search initialized with score of: 32.
# Search ended with best score of 16.
# Restarting. 31,343,504 board positions searched, best score 4.  Loop: 1,221.
# Search initialized with score of: 34.
# Search ended with best score of 12.
# Restarting. 31,434,654 board positions searched, best score 4.  Loop: 1,225.
# Search initialized with score of: 32.
# Search ended with best score of 6.
# Restarting. 31,552,661 board positions searched, best score 4.  Loop: 1,230.
# Search initialized with score of: 30.
# Search ended with best score of 6.
# Restarting. 31,724,295 board positions searched, best score 4.  Loop: 1,236.
# Search initialized with score of: 26.
# Search ended with best score of 12.
# Restarting. 31,788,387 board positions searched, best score 4.  Loop: 1,239.
# Search initialized with score of: 30.
# Search ended with best score of 16.
# Restarting. 31,876,659 board positions searched, best score 4.  Loop: 1,242.
# Search initialized with score of: 30.
# Search ended with best score of 14.
# Restarting. 31,940,751 board positions searched, best score 4.  Loop: 1,245.
# Search initialized with score of: 24.
# Search ended with best score of 14.
# Restarting. 32,004,843 board positions searched, best score 4.  Loop: 1,248.
# Search initialized with score of: 34.
# Search ended with best score of 8.
# Restarting. 32,146,871 board positions searched, best score 4.  Loop: 1,253.
# Search initialized with score of: 30.
# Search ended with best score of 8.
# Restarting. 32,264,569 board positions searched, best score 4.  Loop: 1,258.
# Search initialized with score of: 24.
# Search ended with best score of 12.
# Restarting. 32,328,661 board positions searched, best score 4.  Loop: 1,261.
# Search initialized with score of: 22.
# Search ended with best score of 10.
# Restarting. 32,392,753 board positions searched, best score 4.  Loop: 1,264.
# Search initialized with score of: 30.
# Search ended with best score of 18.
# Restarting. 32,456,896 board positions searched, best score 4.  Loop: 1,267.
# Search initialized with score of: 24.
# Search ended with best score of 8.
# Restarting. 32,548,149 board positions searched, best score 4.  Loop: 1,271.
# Search initialized with score of: 34.
# Search ended with best score of 8.
# Restarting. 32,665,949 board positions searched, best score 4.  Loop: 1,276.
# ...
# Search initialized with score of: 26.
# Search ended with best score of 8.
# Restarting. 95,917,822 board positions searched, best score 2.  Loop: 3,740.
# Search initialized with score of: 22.
# Search ended with best score of 6.
# Restarting. 96,035,622 board positions searched, best score 2.  Loop: 3,745.
# Search initialized with score of: 28.
# Search ended with best score of 12.
# Restarting. 96,126,478 board positions searched, best score 2.  Loop: 3,748.
# Search initialized with score of: 32.
# Search ended with best score of 12.
# Restarting. 96,217,526 board positions searched, best score 2.  Loop: 3,752.
# Search initialized with score of: 28.
# Search ended with best score of 10.
# Restarting. 96,308,472 board positions searched, best score 2.  Loop: 3,756.
# Search initialized with score of: 34.
# Search ended with best score of 10.
# Restarting. 96,399,418 board positions searched, best score 2.  Loop: 3,760.
# Search initialized with score of: 24.
# Search ended with best score of 12.
# Restarting. 96,463,561 board positions searched, best score 2.  Loop: 3,763.
# Search initialized with score of: 30.
# Search ended with best score of 8.
# Restarting. 96,581,519 board positions searched, best score 2.  Loop: 3,768.
# Search initialized with score of: 34.
# Search ended with best score of 12.
# Restarting. 96,726,119 board positions searched, best score 2.  Loop: 3,773.
# Search initialized with score of: 28.
# Search ended with best score of 4.
# Restarting. 96,897,886 board positions searched, best score 2.  Loop: 3,780.
# Search initialized with score of: 32.
# Search ended with best score of 8.
# Restarting. 96,988,832 board positions searched, best score 2.  Loop: 3,784.
# Search initialized with score of: 20.
# Search ended with best score of 8.
# Restarting. 97,079,787 board positions searched, best score 2.  Loop: 3,787.
# Search initialized with score of: 28.
# Search ended with best score of 12.
# Restarting. 97,170,682 board positions searched, best score 2.  Loop: 3,791.
# Search initialized with score of: 30.
# Search ended with best score of 8.
# Restarting. 97,261,577 board positions searched, best score 2.  Loop: 3,795.
# Search initialized with score of: 24.
# Search ended with best score of 12.
# Restarting. 97,352,574 board positions searched, best score 2.  Loop: 3,799.
# Search initialized with score of: 32.
# Search ended with best score of 8.
# Restarting. 97,521,090 board positions searched, best score 2.  Loop: 3,804.
# Search initialized with score of: 28.
# Search ended with best score of 8.
# Restarting. 97,665,507 board positions searched, best score 2.  Loop: 3,809.
# Search initialized with score of: 32.
# Search ended with best score of 14.
# Restarting. 97,729,599 board positions searched, best score 2.  Loop: 3,812.
# Search initialized with score of: 36.
# Search ended with best score of 12.
# Restarting. 97,844,821 board positions searched, best score 2.  Loop: 3,816.
# Search initialized with score of: 36.
# Search ended with best score of 10.
# Restarting. 97,962,781 board positions searched, best score 2.  Loop: 3,821.
# Search initialized with score of: 30.
# Search ended with best score of 14.
# Restarting. 98,027,177 board positions searched, best score 2.  Loop: 3,824.
# Search initialized with score of: 32.
# Search ended with best score of 10.
# Restarting. 98,145,444 board positions searched, best score 2.  Loop: 3,828.
# Search initialized with score of: 28.
# Search ended with best score of 10.
# Restarting. 98,236,449 board positions searched, best score 2.  Loop: 3,831.
# Search initialized with score of: 26.
# Search ended with best score of 12.
# Restarting. 98,300,541 board positions searched, best score 2.  Loop: 3,834.
# Search initialized with score of: 28.
# Search ended with best score of 12.
# Restarting. 98,391,794 board positions searched, best score 2.  Loop: 3,838.
# Search initialized with score of: 30.
# Search ended with best score of 8.
# Restarting. 98,509,555 board positions searched, best score 2.  Loop: 3,842.
# Search initialized with score of: 38.
# Search ended with best score of 10.
# Restarting. 98,654,455 board positions searched, best score 2.  Loop: 3,847.
# Search initialized with score of: 32.
# Search ended with best score of 12.
# Restarting. 98,742,726 board positions searched, best score 2.  Loop: 3,850.
# Search initialized with score of: 30.
# Search ended with best score of 4.
# Restarting. 98,914,708 board positions searched, best score 2.  Loop: 3,856.
# Search initialized with score of: 20.
# Search ended with best score of 8.
# Restarting. 98,978,851 board positions searched, best score 2.  Loop: 3,859.
# Search initialized with score of: 32.
# Search ended with best score of 12.
# Restarting. 99,067,472 board positions searched, best score 2.  Loop: 3,862.
# Search initialized with score of: 26.
# Search ended with best score of 8.
# Restarting. 99,212,486 board positions searched, best score 2.  Loop: 3,868.
# Search initialized with score of: 22.
# Search ended with best score of 10.
# Restarting. 99,276,578 board positions searched, best score 2.  Loop: 3,871.
# Search initialized with score of: 28.
# Search ended with best score of 8.
# Restarting. 99,394,385 board positions searched, best score 2.  Loop: 3,876.
# Search initialized with score of: 24.
# Search ended with best score of 8.
# Restarting. 99,485,389 board positions searched, best score 2.  Loop: 3,880.
# Search initialized with score of: 34.
# Search ended with best score of 10.
# Restarting. 99,600,672 board positions searched, best score 2.  Loop: 3,884.
# Search initialized with score of: 26.
# Search ended with best score of 6.
# Restarting. 99,691,618 board positions searched, best score 2.  Loop: 3,887.
# Search initialized with score of: 22.
# Search ended with best score of 8.
# Restarting. 99,779,889 board positions searched, best score 2.  Loop: 3,890.
# Search initialized with score of: 32.
# Search ended with best score of 8.
# Restarting. 99,921,908 board positions searched, best score 2.  Loop: 3,895.
# Search initialized with score of: 26.
# Search ended with best score of 12.
# Restarting. 100,010,529 board positions searched, best score 2.  Loop: 3,898.
# Search initialized with score of: 38.
# Search ended with best score of 8.
# Restarting. 100,155,339 board positions searched, best score 2.  Loop: 3,904.
# Search initialized with score of: 30.
# Search ended with best score of 12.
# Restarting. 100,243,611 board positions searched, best score 2.  Loop: 3,907.
# Search initialized with score of: 34.
# Search ended with best score of 8.
# Restarting. 100,385,946 board positions searched, best score 2.  Loop: 3,912.
# Search initialized with score of: 28.
# Search ended with best score of 16.
# Restarting. 100,450,038 board positions searched, best score 2.  Loop: 3,915.
# Search initialized with score of: 30.
# Search ended with best score of 10.
# Restarting. 100,541,137 board positions searched, best score 2.  Loop: 3,919.
# Search initialized with score of: 36.
# Search ended with best score of 12.
# Restarting. 100,629,510 board positions searched, best score 2.  Loop: 3,922.
# Search initialized with score of: 30.
# Search ended with best score of 12.
# Restarting. 100,693,653 board positions searched, best score 2.  Loop: 3,925.
# Search initialized with score of: 30.
# Search ended with best score of 10.
# Restarting. 100,784,858 board positions searched, best score 2.  Loop: 3,929.
# Search initialized with score of: 28.
# Search ended with best score of 8.
# Restarting. 100,902,811 board positions searched, best score 2.  Loop: 3,934.
# Search initialized with score of: 20.
# Search ended with best score of 10.
# Restarting. 100,993,808 board positions searched, best score 2.  Loop: 3,938.
# Search initialized with score of: 26.
# Search ended with best score of 12.
# Restarting. 101,058,002 board positions searched, best score 2.  Loop: 3,941.
# Search initialized with score of: 20.
# Search ended with best score of 4.
# Restarting. 101,175,809 board positions searched, best score 2.  Loop: 3,946.
# Search initialized with score of: 22.
# Search ended with best score of 16.
# Restarting. 101,213,088 board positions searched, best score 2.  Loop: 3,948.
# Search initialized with score of: 30.
# Search ended with best score of 4.
# Restarting. 101,357,712 board positions searched, best score 2.  Loop: 3,953.
# Search initialized with score of: 32.
# Search ended with best score of 10.
# Restarting. 101,448,772 board positions searched, best score 2.  Loop: 3,956.
# Search initialized with score of: 30.
# Search ended with best score of 10.
# Restarting. 101,590,903 board positions searched, best score 2.  Loop: 3,960.
# Search initialized with score of: 32.
# Search ended with best score of 8.
# Restarting. 101,681,805 board positions searched, best score 2.  Loop: 3,964.
# Search initialized with score of: 26.
# Search ended with best score of 10.
# Restarting. 101,772,751 board positions searched, best score 2.  Loop: 3,968.
# Search initialized with score of: 32.
# Search ended with best score of 8.
# Restarting. 101,888,179 board positions searched, best score 2.  Loop: 3,972.
# Search initialized with score of: 36.
# Search ended with best score of 8.
# Restarting. 102,056,762 board positions searched, best score 2.  Loop: 3,977.
# Search initialized with score of: 34.
# Search ended with best score of 8.
# Restarting. 102,198,787 board positions searched, best score 2.  Loop: 3,982.
# Search initialized with score of: 30.
# Search ended with best score of 10.
# Restarting. 102,316,485 board positions searched, best score 2.  Loop: 3,987.
# Search initialized with score of: 28.
# Search ended with best score of 10.
# Restarting. 102,407,431 board positions searched, best score 2.  Loop: 3,991.
# Search initialized with score of: 26.
# Search ended with best score of 6.
# Restarting. 102,498,326 board positions searched, best score 2.  Loop: 3,995.
# Search initialized with score of: 26.
# Search ended with best score of 10.
# Restarting. 102,704,351 board positions searched, best score 2.  Loop: 4,003.
# Search initialized with score of: 24.
# Search ended with best score of 6.
# Restarting. 102,795,399 board positions searched, best score 2.  Loop: 4,007.
# Search initialized with score of: 30.
# Search ended with best score of 10.
# Restarting. 102,886,549 board positions searched, best score 2.  Loop: 4,011.
# Search initialized with score of: 16.
# Search ended with best score of 6.
# Restarting. 102,950,641 board positions searched, best score 2.  Loop: 4,014.
# Search initialized with score of: 24.
# Search ended with best score of 4.
# Restarting. 103,068,543 board positions searched, best score 2.  Loop: 4,018.
# Search initialized with score of: 30.
# Search ended with best score of 10.
# Restarting. 103,186,108 board positions searched, best score 2.  Loop: 4,022.
# Search initialized with score of: 36.
# Search ended with best score of 10.
# Restarting. 103,304,017 board positions searched, best score 2.  Loop: 4,027.
# Search initialized with score of: 28.
# Search ended with best score of 12.
# Restarting. 103,395,167 board positions searched, best score 2.  Loop: 4,031.
# Search initialized with score of: 24.
# Search ended with best score of 14.
# Restarting. 103,459,460 board positions searched, best score 2.  Loop: 4,034.
# Search initialized with score of: 28.
# Search ended with best score of 8.
# Restarting. 103,577,413 board positions searched, best score 2.  Loop: 4,039.
# Search initialized with score of: 30.
# Search ended with best score of 8.
# Restarting. 103,719,258 board positions searched, best score 2.  Loop: 4,043.
# Search initialized with score of: 32.
# Search ended with best score of 10.
# Restarting. 103,864,221 board positions searched, best score 2.  Loop: 4,049.
# Search initialized with score of: 32.
# Search ended with best score of 8.
# Restarting. 103,981,926 board positions searched, best score 2.  Loop: 4,054.
# Search initialized with score of: 32.
# Search ended with best score of 10.
# Restarting. 104,100,034 board positions searched, best score 2.  Loop: 4,059.
# Search initialized with score of: 28.
# Search ended with best score of 6.
# Restarting. 104,217,936 board positions searched, best score 2.  Loop: 4,064.
# Search initialized with score of: 16.
# Search ended with best score of 10.
# Restarting. 104,282,130 board positions searched, best score 2.  Loop: 4,067.
# Search initialized with score of: 28.
# Search ended with best score of 16.
# Restarting. 104,346,324 board positions searched, best score 2.  Loop: 4,070.
# Search initialized with score of: 28.
# Search ended with best score of 12.
# Restarting. 104,437,270 board positions searched, best score 2.  Loop: 4,074.
# Search initialized with score of: 28.
# Search ended with best score of 10.
# Restarting. 104,528,420 board positions searched, best score 2.  Loop: 4,078.
# Search initialized with score of: 24.
# Search ended with best score of 10.
# Restarting. 104,619,417 board positions searched, best score 2.  Loop: 4,082.
# Search initialized with score of: 24.
# Search ended with best score of 10.
# Restarting. 104,683,560 board positions searched, best score 2.  Loop: 4,085.
# Search initialized with score of: 34.
# Search ended with best score of 6.
# Restarting. 104,828,031 board positions searched, best score 2.  Loop: 4,089.
# Search initialized with score of: 22.
# Search ended with best score of 12.
# Restarting. 104,892,123 board positions searched, best score 2.  Loop: 4,092.
# Search initialized with score of: 34.
# Search ended with best score of 6.
# Restarting. 105,063,859 board positions searched, best score 2.  Loop: 4,098.
# Search initialized with score of: 34.
# Search ended with best score of 12.
# Restarting. 105,127,951 board positions searched, best score 2.  Loop: 4,101.
# Search initialized with score of: 28.
# Search ended with best score of 12.
# Restarting. 105,192,043 board positions searched, best score 2.  Loop: 4,104.
# Search initialized with score of: 28.
# Search ended with best score of 8.
# Restarting. 105,282,938 board positions searched, best score 2.  Loop: 4,108.
# Search initialized with score of: 42.
# Search ended with best score of 10.
# Restarting. 105,422,746 board positions searched, best score 2.  Loop: 4,112.
# Search initialized with score of: 30.
# Search ended with best score of 8.
# Restarting. 105,486,838 board positions searched, best score 2.  Loop: 4,115.
# Search initialized with score of: 24.
# Search ended with best score of 14.
# Restarting. 105,524,117 board positions searched, best score 2.  Loop: 4,117.
# Search initialized with score of: 32.
# Search ended with best score of 14.
# Restarting. 105,612,389 board positions searched, best score 2.  Loop: 4,120.
# Search initialized with score of: 28.
# Search ended with best score of 14.
# Restarting. 105,676,481 board positions searched, best score 2.  Loop: 4,123.
# Search initialized with score of: 34.
# Search ended with best score of 6.
# Restarting. 105,821,298 board positions searched, best score 2.  Loop: 4,128.
# Search initialized with score of: 24.
# Search ended with best score of 10.
# Restarting. 105,939,200 board positions searched, best score 2.  Loop: 4,133.
# Search initialized with score of: 26.
# Search ended with best score of 6.
# Restarting. 106,057,012 board positions searched, best score 2.  Loop: 4,137.
# Search initialized with score of: 28.
# Search ended with best score of 8.
# Restarting. 106,201,588 board positions searched, best score 2.  Loop: 4,142.
# Search initialized with score of: 30.
# Search ended with best score of 14.
# Restarting. 106,265,680 board positions searched, best score 2.  Loop: 4,145.
# Search initialized with score of: 32.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-544656801e19> in <module>()
#      21         best_score=np.infty
#      22     for C in C_list:
# ---> 23         s = score(C)
#      24         if s < best_score:
#      25             best_C_list.append(C.copy())
#
# <ipython-input-9-047af77e24b9> in score(C)
#       7         for unit in pieces[i].rot_list(C[i,2]):
#       8             x = C[i][0] + unit[0]
# ----> 9             y = C[i][1] + unit[1]
#      10             if (min(x,y) < 0) or (max(x,y) > 6):
#      11                 return np.infty
#
# KeyboardInterrupt:

# %%
best_chrom_ever
